# %% [markdown]
# # Preprocess corpus

# %%
import pandas as pd

class ProcessCorpus:
    def __init__(self, filepath='/kaggle/input/bkai-ai-track2-legal-document-retrieval/Legal Document Retrieval/corpus.csv'):
        self.df = pd.read_csv(filepath, usecols=['text', 'cid'])

    def process_text(self):
        self.df['text'] = self.df['text'].apply(lambda x: ' '.join(x.split()))
        self.save_to_csv()

    def save_to_csv(self):
        output_path = 'preprocessed_corpus.csv'
        self.df.to_csv(output_path, index=False)


if __name__ == "__main__":
    processor = ProcessCorpus()
    processor.process_text()

# %% [markdown]
# # Encode
# - preprocessed_corpus.csv to encoded_corpus.json
# - public_test.csv to encoded_public_test.json
# - train.csv to encoded_train_full.json

# %%
import pandas as pd
import numpy as np
import torch
# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

# Encode corpus.csv
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

df = pd.read_csv('/kaggle/input/preprocessed-corpus/preprocessed_corpus.csv')

model = SentenceTransformer('bkai-foundation-models/vietnamese-bi-encoder')
model = model.to(device)

def encode(lst = [], convert_to_tensor=True, batch_size=128):
    vectors = []
    with tqdm(total = len(lst), desc="Encoding texts") as pbar:
        # Process in batches
        for i in range(0, len(lst), batch_size):
            batch = lst[i:i + batch_size]
            encoded_batch = model.encode(batch, convert_to_tensor=True, device=device)
            # Move to CPU before converting to numpy
            if torch.cuda.is_available():
                encoded_batch = encoded_batch.cpu()
            vectors.extend([np.array(arr) for arr in encoded_batch.numpy()])
            pbar.update(len(batch))
    return vectors

df['vector'] = encode(lst=list(df['text']))

df.to_json('encoded_corpus.json')
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: sentence_transformers in /opt/conda/lib/python3.10/site-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (4.45.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (2.4.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (0.25.1)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (10.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.20.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.20.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Encoding texts:   0%|          | 0/261597 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   0%|          | 128/261597 [00:01<44:54, 97.03it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   0%|          | 256/261597 [00:02<35:52, 121.39it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   0%|          | 384/261597 [00:03<32:43, 133.03it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   0%|          | 512/261597 [00:03<31:08, 139.72it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   0%|          | 640/261597 [00:04<30:19, 143.41it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   0%|          | 768/261597 [00:05<30:42, 141.54it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   0%|          | 896/261597 [00:06<30:32, 142.29it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   0%|          | 1024/261597 [00:07<30:30, 142.33it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   0%|          | 1152/261597 [00:08<31:09, 139.28it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   0%|          | 1280/261597 [00:09<30:26, 142.49it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 1408/261597 [00:10<30:03, 144.31it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 1536/261597 [00:11<30:53, 140.31it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 1664/261597 [00:11<30:01, 144.26it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 1792/261597 [00:12<29:19, 147.62it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 1920/261597 [00:13<28:52, 149.84it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 2048/261597 [00:14<29:32, 146.44it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 2176/261597 [00:15<29:00, 149.04it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 2304/261597 [00:16<28:53, 149.58it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 2432/261597 [00:17<29:16, 147.51it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 2560/261597 [00:17<29:27, 146.52it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 2688/261597 [00:18<29:01, 148.69it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 2816/261597 [00:19<28:37, 150.71it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 2944/261597 [00:20<28:01, 153.83it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 3072/261597 [00:21<28:20, 152.04it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 3200/261597 [00:22<28:59, 148.52it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|▏         | 3328/261597 [00:23<29:15, 147.09it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|▏         | 3456/261597 [00:23<29:41, 144.92it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|▏         | 3584/261597 [00:24<29:18, 146.76it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|▏         | 3712/261597 [00:25<28:55, 148.60it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   1%|▏         | 3840/261597 [00:26<28:58, 148.24it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:   2%|▏         |
/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 30976/261597 [03:40<26:46, 143.55it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 31104/261597 [03:41<26:51, 143.00it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 31232/261597 [03:42<27:41, 138.63it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 31360/261597 [03:43<28:42, 133.66it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 31488/261597 [03:44<28:45, 133.38it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 31616/261597 [03:45<26:50, 142.80it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 31744/261597 [03:45<26:15, 145.87it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 31872/261597 [03:46<27:19, 140.09it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 32000/261597 [03:47<27:08, 140.96it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 32128/261597 [03:48<27:35, 138.58it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 32256/261597 [03:49<26:42, 143.15it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 32384/261597 [03:50<26:55, 141.85it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 32512/261597 [03:51<26:47, 142.52it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  12%|█▏        | 32640/261597 [03:52<26:35, 143.47it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 32768/261597 [03:53<27:12, 140.17it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 32896/261597 [03:54<27:27, 138.80it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 33024/261597 [03:55<27:20, 139.32it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 33152/261597 [03:55<27:26, 138.71it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 33280/261597 [03:56<26:10, 145.41it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 33408/261597 [03:57<25:50, 147.16it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 33536/261597 [03:58<26:28, 143.56it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 33664/261597 [03:59<26:23, 143.92it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 33792/261597 [04:00<25:12, 150.62it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 33920/261597 [04:01<25:51, 146.78it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  13%|█▎        | 33920/261597 [04:01<27:00, 140.47it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 30
#      27             pbar.update(len(batch))
#      28     return vectors
# ---> 30 df['vector'] = encode(lst=list(df['text']))
#      32 df.to_json('encoded_corpus.json')
#
# Cell In[2], line 22, in encode(lst, convert_to_tensor, batch_size)
#      20 for i in range(0, len(lst), batch_size):
#      21     batch = lst[i:i + batch_size]
# ---> 22     encoded_batch = model.encode(batch, convert_to_tensor=True, device=device)
#      23     # Move to CPU before converting to numpy
#      24     if torch.cuda.is_available():
#
# File /opt/conda/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:619, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     610         if "token_type_ids" in features:
#     611             features["token_type_ids"] = torch.cat(
#     612                 (
#     613                     features["token_type_ids"],
#    (...)
#     616                 -1,
#     617             )
# --> 619 features = batch_to_device(features, device)
#     620 features.update(extra_features)
#     622 with torch.no_grad():
#
# File /opt/conda/lib/python3.10/site-packages/sentence_transformers/util.py:1067, in batch_to_device(batch, target_device)
#    1065 for key in batch:
#    1066     if isinstance(batch[key], Tensor):
# -> 1067         batch[key] = batch[key].to(target_device)
#    1068 return batch
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import torch
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

# Encode public_test
df = pd.read_csv('/kaggle/input/bkai-ai-track2-legal-document-retrieval/Legal Document Retrieval/public_test.csv')

device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = SentenceTransformer('bkai-foundation-models/vietnamese-bi-encoder', device=device)

def encode(lst = [], convert_to_tensor=True, batch_size=128):
    vectors = []
    with tqdm(total=len(lst), desc="Encoding questions") as pbar:
        for i in range(0, len(lst), batch_size):
            batch = lst[i:i + batch_size]
            encoded_batch = model.encode(batch, convert_to_tensor=True)
            if device == 'cuda':
                encoded_batch = encoded_batch.cpu()
            vectors.extend([np.array(arr) for arr in encoded_batch.numpy()])
            pbar.update(len(batch))
    return vectors

df['question_vector'] = encode(lst=list(df['question']))

output_df = df[['question', 'qid', 'question_vector']]

output_df.to_json('encoded_public_test.json')
# Out:
# Encoding questions:   0%|          | 0/10000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions
/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  67%|██████▋   | 6656/10000 [00:07<00:03, 900.65it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  68%|██████▊   | 6784/10000 [00:07<00:03, 885.90it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  69%|██████▉   | 6912/10000 [00:07<00:03, 869.87it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  70%|███████   | 7040/10000 [00:07<00:03, 869.20it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  72%|███████▏  | 7168/10000 [00:08<00:03, 863.47it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  73%|███████▎  | 7296/10000 [00:08<00:03, 864.97it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  74%|███████▍  | 7424/10000 [00:08<00:02, 869.88it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  76%|███████▌  | 7552/10000 [00:08<00:02, 870.38it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  77%|███████▋  | 7680/10000 [00:08<00:02, 881.90it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  78%|███████▊  | 7808/10000 [00:08<00:02, 881.36it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  79%|███████▉  | 7936/10000 [00:08<00:02, 878.05it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  81%|████████  | 8064/10000 [00:09<00:02, 867.59it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  82%|████████▏ | 8192/10000 [00:09<00:02, 876.66it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  83%|████████▎ | 8320/10000 [00:09<00:02, 782.35it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  84%|████████▍ | 8448/10000 [00:09<00:01, 800.88it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  86%|████████▌ | 8576/10000 [00:09<00:01, 836.51it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  87%|████████▋ | 8704/10000 [00:09<00:01, 862.35it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  88%|████████▊ | 8832/10000 [00:10<00:01, 868.03it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  90%|████████▉ | 8960/10000 [00:10<00:01, 882.80it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  91%|█████████ | 9088/10000 [00:10<00:01, 875.23it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  92%|█████████▏| 9216/10000 [00:10<00:00, 881.47it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  93%|█████████▎| 9344/10000 [00:10<00:00, 870.07it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  95%|█████████▍| 9472/10000 [00:10<00:00, 875.38it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  96%|█████████▌| 9600/10000 [00:10<00:00, 875.78it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  97%|█████████▋| 9728/10000 [00:11<00:00, 877.90it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions:  99%|█████████▊| 9856/10000 [00:11<00:00, 890.36it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding questions: 100%|█████████▉| 9984/10000 [00:11<00:00, 906.29it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Encoding questions: 100%|██████████| 10000/10000 [00:11<00:00, 877.61it/s]

# %%
import pandas as pd
import numpy as np
import torch
# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

# Encode train.csv
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

df = pd.read_csv('/kaggle/input/bkai-ai-track2-legal-document-retrieval/Legal Document Retrieval/train.csv')

model = SentenceTransformer('bkai-foundation-models/vietnamese-bi-encoder')
model = model.to(device)

def encode(lst = [], convert_to_tensor=True, batch_size=1024):
    vectors = []
    with tqdm(total=len(lst), desc="Encoding texts") as pbar:
        # Process in batches
        for i in range(0, len(lst), batch_size):
            batch = lst[i:i + batch_size]
            encoded_batch = model.encode(batch, convert_to_tensor=True, device=device)
            # Move to CPU before converting to numpy
            if torch.cuda.is_available():
                encoded_batch = encoded_batch.cpu()
            vectors.extend([np.array(arr) for arr in encoded_batch.numpy()])
            pbar.update(len(batch))
    return vectors

df['question_vector'] = encode(lst=list(df['question']))

df.to_json('encoded_train_full.json')
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: sentence_transformers in /opt/conda/lib/python3.10/site-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (4.45.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (2.4.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (0.25.1)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (10.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.20.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.20.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Encoding texts:   0%|          | 0/119456 [00:00<?, ?it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:   1%|          | 1024/119456 [00:00<01:51, 1066.36it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:   2%|▏         | 2048/119456 [00:01<01:48, 1085.04it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:   3%|▎         | 3072/119456 [00:02<01:47, 1085.77it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:   3%|▎         | 4096/119456 [00:03<01:46, 1082.50it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:   4%|▍         |
/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  89%|████████▉ | 106496/119456 [01:39<00:12, 1066.41it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  90%|█████████ | 107520/119456 [01:40<00:11, 1073.94it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  91%|█████████ | 108544/119456 [01:41<00:10, 1082.56it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  92%|█████████▏| 109568/119456 [01:42<00:09, 1087.60it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  93%|█████████▎| 110592/119456 [01:43<00:08, 1084.32it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  93%|█████████▎| 111616/119456 [01:44<00:07, 1076.31it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  94%|█████████▍| 112640/119456 [01:44<00:06, 1073.93it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  95%|█████████▌| 113664/119456 [01:45<00:05, 1075.24it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  96%|█████████▌| 114688/119456 [01:46<00:04, 1070.35it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  97%|█████████▋| 115712/119456 [01:47<00:03, 1068.12it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  98%|█████████▊| 116736/119456 [01:48<00:02, 1065.94it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▊| 117760/119456 [01:49<00:01, 1074.29it/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 118784/119456 [01:50<00:00, 1071.94it/s]
# Batches:   0%|          | 0/21 [00:00<?, ?it/s]
# Encoding texts: 100%|██████████| 119456/119456 [01:51<00:00, 1072.47it/s]

# %% [markdown]
# # Create a dissimilarity list and negative pairing

# %%
import torch
import torch.nn.functional as F
import pandas as pd
import zipfile
import json

# Input: corpus and training dataset
# Output: dissimilarity list

train_df = pd.read_json('/kaggle/input/encodedtrainfull/encoded_train_full.json')
corpus_df = pd.read_json('/kaggle/input/encoded/encoded_corpus.json')

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

train_ids = train_df['qid'].tolist()
train_vectors = torch.tensor(train_df['question_vector'].tolist(), dtype=torch.float32).to(device)
corpus_ids = corpus_df['cid'].tolist()
corpus_vectors = torch.tensor(corpus_df['vector'].tolist(), dtype=torch.float32).to(device)

train_vectors = F.normalize(train_vectors, p=2, dim=1)
corpus_vectors = F.normalize(corpus_vectors, p=2, dim=1)

json_results = []
batch_size = 256

with open('predict_most_dissimilar.txt', 'w') as f:
    for i in range(0, len(train_ids), batch_size): 
        # Process in batches
        batch_train_vectors = train_vectors[i:i+batch_size]
        batch_train_ids = train_ids[i:i+batch_size]
        
        similarity_matrix = torch.matmul(batch_train_vectors, corpus_vectors.T)
        
        min_values, min_indices = torch.min(similarity_matrix, dim=1)
        
        for j, (idx, score) in enumerate(zip(min_indices, min_values)):
            qid = batch_train_ids[j]
            cid = str(corpus_ids[idx.item()])
            
            f.write(f"{qid} {cid}\n")

            json_entry = {
                "query_id": qid,
                "candidates": {
                    "doc_ids": [cid],
                    "scores": [score.item()],
                }
            }
            json_results.append(json_entry)

with open('predict_most_dissimilar.json', 'w', encoding='utf-8') as f:
    json.dump(json_results, f, ensure_ascii=False, indent=2)

with zipfile.ZipFile('predict_most_dissimilar.zip', 'w') as zipf:
    zipf.write('predict_most_dissimilar.txt')
    zipf.write('predict_most_dissimilar.json')
# Out:
# Using device: cuda

# %%
import os
import subprocess
from IPython.display import FileLink, display

# Download the dissimilarity list to local

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))

# download_file('/kaggle/working', 'encoded_public_test_finetuned')
download_file('/kaggle/working', 'predict_dissimilar')
# Out:
# /kaggle/working/predict_dissimilar.zip

# %%
import pandas as pd
import json
import numpy as np

#Input: 
''' 
        DataFrames: df_train, df_corpus - csv input
        json: predict_most_dissimilar.json - 
    '''
#Output
''' 
        json: fine_tune_training.json -> will be used to fine-tune the model
    '''



df_train = pd.read_csv('/kaggle/input/bkai-ai-track2-legal-document-retrieval/Legal Document Retrieval/train.csv', on_bad_lines='skip')
df_corpus = pd.read_csv('/kaggle/input/preprocessed-corpus/preprocessed_corpus.csv')

with open('/kaggle/input/predict-dissimilar/kaggle/working/predict_most_dissimilar.json', 'r') as f:
    predictions = json.load(f)

training_data = []

for pred in predictions:
    qid = pred['query_id']
    neg_cid = pred['candidates']['doc_ids'][0]  #Negative cid
    
    # Query text from train.csv
    query_row = df_train[df_train['qid'] == qid]
    if query_row.empty:
        continue
    query_text = query_row['question'].iloc[0]
    
    # Positive -> ground truth - given in train.csv
    ground_truth_str = query_row['cid'].iloc[0]
    ground_truth_cids = ground_truth_str.strip('[]').split()
    pos_cid = ground_truth_cids[0]  
    
    pos_matches = df_corpus.loc[df_corpus['cid'] == int(pos_cid), 'text']
    neg_matches = df_corpus.loc[df_corpus['cid'] == int(neg_cid), 'text']
    
    if pos_matches.empty or neg_matches.empty:
        continue  
    
    pos_text = pos_matches.iloc[0]
    neg_text = neg_matches.iloc[0]
    
    entry = {
        "query": query_text,
        "pos": [pos_text],
        "neg": [neg_text]
    }
    training_data.append(entry)

with open('fine_tune_training.json', 'w', encoding='utf-8') as f:
    for entry in training_data:
        f.write(json.dumps(entry, ensure_ascii=False) + '\n')

# %% [markdown]
# # Fine-tune bkai-foundation-models/vietnamese-bi-encoder
# - Use the given fine_tune_training.json to fine-tune the model
# - This part was originally done on a high-performance server with a RTX 4090, but for demonstrative purpose, we will utilize Kaggle for now.
# - Since the waiting time would be rigorous, in this code we only run with 1 epoch, while the orignal version ran with 3.

# %%
from datasets import Dataset, load_dataset
import os
! pip install -U accelerate
! pip install -U transformers sentence_transformers
os.environ["WANDB_DISABLED"] = "true"
import json
from sentence_transformers import (
    SentenceTransformer,
    losses,
    InputExample
)
from torch.utils.data import DataLoader


'''
    #Input:
    Model: bkai-foundation-models/vietnamese-bi-encoder
    Negative pairing dataset: fine_tune_training.json

    #Output:
    Fine-tuned model.
'''

model = SentenceTransformer('bkai-foundation-models/vietnamese-bi-encoder')

def load_json_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = [json.loads(line) for line in f]
    
    train_examples = []
    for item in data:
        query = item['query']
        pos = item['pos'][0] 
        
        # Positive
        train_examples.append(InputExample(
            texts=[query, pos],
            label=1.0  
        ))
        
        # Negative
        for neg in item['neg']:
            train_examples.append(InputExample(
                texts=[query, neg],
                label=0.0 
            ))
    
    return train_examples

train_examples = load_json_data('/kaggle/input/negativepairing/fine_tune_training.json')

train_dataloader = DataLoader(
    train_examples,
    shuffle=True,
    batch_size=48
)

train_loss = losses.MultipleNegativesRankingLoss(model)

warmup_steps = int(len(train_dataloader) * 0.1)  

model.fit(
    train_objectives=[(train_dataloader, train_loss)],
    epochs=1, #Kaggle: 1 epoch - HPC: 3 epochs
    warmup_steps=warmup_steps,
    optimizer_params={'lr': 2e-5},
    output_path='/kaggle/working/finetuned',
    save_best_model=True,
    show_progress_bar=True,
    checkpoint_path='/kaggle/working/checkpoints',
    checkpoint_save_steps=7500,  
    checkpoint_save_total_limit=1 
)

model.save('/kaggle/working/final')
# Out:
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.34.2)
# Collecting accelerate
#   Downloading accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.4.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-1.2.1-py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.4/336.4 kB 9.2 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.34.2
#     Uninstalling accelerate-0.34.2:
#       Successfully uninstalled accelerate-0.34.2
# Successfully installed accelerate-1.2.1
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Collecting transformers
#   Downloading transformers-4.48.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.0 MB/s eta 0:00:00
# Collecting sentence_transformers
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (2.4.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.14.1)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (10.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Downloading transformers-4.48.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 79.1 MB/s eta 0:00:00:00:0100:01
# Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 16.1 MB/s eta 0:00:00
# Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 83.5 MB/s eta 0:00:00:00:01
# Installing collected packages: tokenizers, transformers, sentence_transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.0
#     Uninstalling tokenizers-0.20.0:
#       Successfully uninstalled tokenizers-0.20.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.45.1
#     Uninstalling transformers-4.45.1:
#       Successfully uninstalled transformers-4.45.1
# Successfully installed sentence_transformers-3.3.1 tokenizers-0.21.0 transformers-4.48.0
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/6.46k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
#     <div>
#
#       <progress value='4957' max='4957' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4957/4957 1:53:53, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>3.084500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.987400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.683600</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.501000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.370300</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.264400</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.206300</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.132600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.122100</td>
#     </tr>
#   </tbody>
# </table><p>
# Computing widget examples:   0%|          | 0/1 [00:00<?, ?example/s]

# %%
import os
import subprocess
from IPython.display import FileLink, display

#Save finetuned model(1 epoch version)
def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))

# download_file('/kaggle/working', 'encoded_public_test_finetuned')
download_file('encoded_corpus_finetuned.json', 'encoded_corpus_finetuned')
# Out:
# /kaggle/working/encoded_corpus_finetuned.zip

# %% [markdown]
# # Encode with fine-tuned model
# - preprocessed_corpus.csv to encoded_corpus_finetuned.json
# - public_test.csv to encoded_public_test_finetuned.json

# %%
import pandas as pd
import numpy as np
import torch
# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

'''
    Input:
        Fine-tuned model: finetuned-biencoder
        preprocessed_corpus.csv
    Output:
        encoded_corpus_finetuned.json
'''

# Encode corpus.csv
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

df = pd.read_csv('/kaggle/input/preprocessed-corpus/preprocessed_corpus.csv')

#Not modified yet
model = SentenceTransformer('/kaggle/input/finetuned-biencoder/final')
model = model.to(device)

def encode(lst = [], convert_to_tensor=True, batch_size=128):
    vectors = []
    with tqdm(total = len(lst), desc="Encoding texts") as pbar:
        # Process in batches
        for i in range(0, len(lst), batch_size):
            batch = lst[i:i + batch_size]
            encoded_batch = model.encode(batch, convert_to_tensor=True, device=device)
            # Move to CPU before converting to numpy
            if torch.cuda.is_available():
                encoded_batch = encoded_batch.cpu()
            vectors.extend([np.array(arr) for arr in encoded_batch.numpy()])
            pbar.update(len(batch))
    return vectors

df['vector'] = encode(lst=list(df['text']))

df.to_json('encoded_corpus_finetuned.json')
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
#
/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  98%|█████████▊| 256896/261597 [29:28<00:31, 147.96it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  98%|█████████▊| 257024/261597 [29:28<00:30, 151.54it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  98%|█████████▊| 257152/261597 [29:29<00:29, 148.91it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  98%|█████████▊| 257280/261597 [29:30<00:28, 149.33it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  98%|█████████▊| 257408/261597 [29:31<00:28, 149.39it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  98%|█████████▊| 257536/261597 [29:32<00:26, 150.62it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  98%|█████████▊| 257664/261597 [29:33<00:27, 144.97it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▊| 257792/261597 [29:34<00:26, 141.39it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▊| 257920/261597 [29:35<00:26, 140.74it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▊| 258048/261597 [29:36<00:25, 138.06it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▊| 258176/261597 [29:37<00:25, 136.47it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▊| 258304/261597 [29:38<00:23, 139.26it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 258432/261597 [29:38<00:22, 143.06it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 258560/261597 [29:39<00:21, 139.08it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 258688/261597 [29:40<00:20, 139.30it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 258816/261597 [29:41<00:19, 141.88it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 258944/261597 [29:42<00:19, 136.28it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 259072/261597 [29:43<00:19, 131.51it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 259200/261597 [29:44<00:18, 132.44it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 259328/261597 [29:45<00:16, 134.76it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 259456/261597 [29:46<00:15, 139.56it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 259584/261597 [29:47<00:14, 142.25it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 259712/261597 [29:48<00:12, 145.26it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 259840/261597 [29:48<00:12, 144.29it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 259968/261597 [29:49<00:10, 148.64it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 260096/261597 [29:50<00:10, 145.03it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts:  99%|█████████▉| 260224/261597 [29:51<00:09, 146.24it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts: 100%|█████████▉| 260352/261597 [29:52<00:08, 141.62it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts: 100%|█████████▉| 260480/261597 [29:53<00:07, 142.26it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts: 100%|█████████▉| 260608/261597 [29:54<00:06, 143.47it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts: 100%|█████████▉| 260736/261597 [29:55<00:06, 142.96it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts: 100%|█████████▉| 260864/261597 [29:56<00:05, 142.06it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts: 100%|█████████▉| 260992/261597 [29:57<00:04, 136.00it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts: 100%|█████████▉| 261120/261597 [29:57<00:03, 142.12it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts: 100%|█████████▉| 261248/261597 [29:58<00:02, 138.45it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts: 100%|█████████▉| 261376/261597 [29:59<00:01, 141.94it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding texts: 100%|█████████▉| 261504/261597 [30:00<00:00, 145.77it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Encoding texts: 100%|██████████| 261597/261597 [30:01<00:00, 145.22it/s]

# %%
import pandas as pd
import numpy as np
import torch
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

'''
    Input:
        Fine-tuned model
        public_test.csv
    Output:
        encoded_public_test_finetuned.json
'''

# Encode public_test
df = pd.read_csv('/kaggle/input/bkai-ai-track2-legal-document-retrieval/Legal Document Retrieval/public_test.csv')

device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = SentenceTransformer('/kaggle/input/finetuned-biencoder/final', device=device)

def encode(lst = [], convert_to_tensor=True, batch_size=128):
    vectors = []
    with tqdm(total=len(lst), desc="Encoding questions") as pbar:
        for i in range(0, len(lst), batch_size):
            batch = lst[i:i + batch_size]
            encoded_batch = model.encode(batch, convert_to_tensor=True)
            if device == 'cuda':
                encoded_batch = encoded_batch.cpu()
            vectors.extend([np.array(arr) for arr in encoded_batch.numpy()])
            pbar.update(len(batch))
    return vectors

df['question_vector'] = encode(lst=list(df['question']))

output_df = df[['question', 'qid', 'question_vector']]

output_df.to_json('encoded_public_test_finetuned.json')

# %% [markdown]
# # Predict the 50 top relevant responses for public_test using the fine-tuned model
# - Input: encoded_corpus_finetuned.json and encoded_public_test.json

# %%
import torch
import torch.nn.functional as F
import pandas as pd
import zipfile
import json
'''
    Input: encoded_corpus_finetuned.json and encoded_public_test.json
    Output: top 50 predictions
'''

train_df = pd.read_json('/kaggle/input/finetuned-corpus-and-test/encoded_public_test_finetuned/kaggle/working/encoded_public_test_finetuned.json')
corpus_df = pd.read_json('/kaggle/input/finetuned-corpus-and-test/encoded_corpus_finetuned/kaggle/working/encoded_corpus.json')

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")


train_ids = train_df['qid'].tolist()
train_vectors = torch.tensor(train_df['vector'].tolist(), dtype=torch.float32).to(device)
corpus_ids = corpus_df['cid'].tolist()
try:
    corpus_vectors = torch.tensor(corpus_df['vector'].tolist(), dtype=torch.float32).to(device)
except:
    corpus_vectors = torch.tensor(corpus_df['question_vector'].tolist(), dtype=torch.float32).to(device)


train_vectors = F.normalize(train_vectors, p=2, dim=1)
corpus_vectors = F.normalize(corpus_vectors, p=2, dim=1)

similarity_matrix = torch.matmul(train_vectors, corpus_vectors.T)

top_k = 50  
top_k_values, top_k_indices = torch.topk(similarity_matrix, k=top_k, dim=1)

json_results = []

with open('predict_top50_finetuned.txt', 'w') as f:
    for i, (indices, scores) in enumerate(zip(top_k_indices, top_k_values)):
        qid = train_ids[i]
        
        top_cids = [str(corpus_ids[idx.item()]) for idx in indices]
        similarity_scores = [score.item() for score in scores]
        
        line = f"{qid} {' '.join(top_cids)}\n"
        f.write(line)
        
        json_entry = {
            "query_id": qid,
            "candidates": {
                "doc_ids": top_cids,
                "scores": similarity_scores,
            }
        }
        json_results.append(json_entry)

with open('predict_top50_finetuned.json', 'w', encoding='utf-8') as f:
    json.dump(json_results, f, ensure_ascii=False, indent=2)

with zipfile.ZipFile('predict_top50_finetuned.zip', 'w') as zipf:
    zipf.write('predict_top50_finetuned.txt')
    zipf.write('predict_top50_finetuned.json')
# Out:
# Using device: cuda

# %% [markdown]
# # Re-rank the top 50 prediction using cross-encoder

# %%
import pandas as pd
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import json

predictions = pd.read_json('/kaggle/input/top50finetuned/predict_top50_finetuned.json')
test_df = pd.read_csv('/kaggle/input/bkai-ai-track2-legal-document-retrieval/Legal Document Retrieval/public_test.csv')
corpus_df = pd.read_csv('/kaggle/input/preprocessed-corpus/preprocessed_corpus.csv')


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
tokenizer = AutoTokenizer.from_pretrained('namdp-ptit/ViRanker')
model = AutoModelForSequenceClassification.from_pretrained('namdp-ptit/ViRanker').to(device)
model.eval()

reranked_results = []

for _, row in predictions.iterrows():
    qid = row['query_id']  
    query_text = test_df['question'][test_df['qid'] == qid].iloc[0]
    doc_ids = row['candidates']['doc_ids']
    
    print(f"Processing qid: {qid}")
    print(f"First few doc_ids: {doc_ids[:3]}")
    
    pairs = []
    for doc_id in doc_ids:
        texts = corpus_df.loc[corpus_df['cid'] == doc_id, 'text'].tolist()
        for text in texts:
            pairs.append((query_text, text))

    batch_size = 8 
    all_scores = []

    with torch.no_grad():
        for i in range(0, len(pairs), batch_size):
            batch_pairs = pairs[i:i + batch_size]
            inputs = tokenizer(batch_pairs, padding=True, truncation=True, 
                            return_tensors='pt', max_length=512)
            inputs = {k: v.to(device) for k, v in inputs.items()}
            
            scores = model(**inputs, return_dict=True).logits.view(-1,).float()
            all_scores.extend(scores.cpu().numpy().tolist())

    json_entry = {
        "query_id": qid,
        "candidates": {
            "doc_ids": doc_ids,
            "scores": all_scores
        }
    }
    reranked_results.append(json_entry)

with open('predict_top50_reranked.json', 'w') as f:
    json.dump(reranked_results, f, indent=2)
# Out:
# Processing qid: 98440
# First few doc_ids: ['77191', '230002', '111380']
# Processing qid: 105737
# First few doc_ids: ['51573', '229317', '470960']
# Processing qid: 106239
# First few doc_ids: ['214239', '101722', '184177']
# Processing qid: 79491
# First few doc_ids: ['50701', '64708', '64709']
# Processing qid: 130557
# First few doc_ids: ['36248', '3788', '193882']
# Processing qid: 109476
# First few doc_ids: ['139187', '557644', '572543']
# Processing qid: 64585
# First few doc_ids: ['136490', '35028', '256964']
# Processing qid: 5785
# First few doc_ids: ['108373', '63709', '65892']
# Processing qid: 159576
# First few doc_ids: ['141320', '126678', '162297']
# Processing qid: 36563
# First few doc_ids: ['534271', '214685', '593864']
# Processing qid: 43191
# First few doc_ids: ['71162', '167857', '71161']
# Processing qid: 139105
# First few doc_ids: ['25388', '73944', '25362']
# Processing qid: 102773
# First few doc_ids: ['88260', '72922', '210050']
# Processing qid: 32598
# First few doc_ids: ['90380', '140526', '236329']
# Processing qid: 31049
# First few doc_ids: ['165714', '177193', '177190']
# Processing qid: 48636
# First few doc_ids: ['136293', '211451', '558143']
# Processing qid: 36430
# First few doc_ids: ['108234', '126652', '35405']
# Processing qid: 39273
# First few doc_ids: ['101047', '582234', '73851']
# Processing qid: 94810
# First few doc_ids: ['167687', '499867', '190162']
# Processing qid: 41901
# First few doc_ids: ['78753', '160775', '59549']
# Processing qid: 42205
# First few doc_ids: ['66010', '18520', '105008']
# Processing qid: 54376
# First few doc_ids: ['150435', '39210', '149427']
# Processing qid: 74364
# First few doc_ids: ['491278', '237578', '68865']
# Processing qid: 85401
# First few doc_ids: ['44253', '9792', '120055']
# Processing qid: 7322
# First few doc_ids: ['65749', '69637', '121653']
# Processing qid: 6087
# First few doc_ids: ['45096', '96062', '31108']
# Processing qid: 45346
# First few doc_ids: ['164709', '112271', '185787']
# Processing qid: 6775
# First few doc_ids: ['69024', '10015', '83330']
# Processing qid: 52699
# First few doc_ids: ['146073', '462920', '129349']
# Processing qid: 38184
# First few doc_ids: ['104243', '25360', '222509']
# Processing qid: 128378
# First few doc_ids: ['45406', '238650', '236750']
# Processing qid: 12814
# First few doc_ids: ['601785', '88030', '134176']
# Processing qid: 17485
# First few doc_ids: ['248751', '96986', '240870']
# Processing qid: 106203
# First few doc_ids: ['99156', '112241', '25583']
# Processing qid: 86763
# First few doc_ids: ['31127', '129633', '13747']
# Processing qid: 113757
# First few doc_ids: ['627908', '202649', '81304']
# Processing qid: 169625
# First few doc_ids: ['86912', '251397', '86914']
# Processing qid: 11171
# First few doc_ids: ['73928', '67137', '155200']
# Processing qid: 151799
# First few doc_ids: ['151443', '194886', '257542']
# Processing qid: 36423
# First few doc_ids: ['138711', '102252', '162801']
# Processing qid: 38649
# First few doc_ids: ['42871', '510965', '525542']
# Processing qid: 61428
# First few doc_ids: ['130292', '230536', '170801']
# Processing qid: 2327
# First few doc_ids: ['47677', '216493', '64021']
# Processing qid: 72764
# First few doc_ids: ['143002', '256235', '143003']
# Processing qid: 127016
# First few doc_ids: ['203739', '235985', '160617']
# Processing qid: 157117
# First few doc_ids: ['128643', '100595', '149013']
# Processing qid: 55077
# First few doc_ids: ['123174', '191361', '154965']
# Processing qid: 124620
# First few doc_ids: ['87583', '201042', '44868']
# Processing qid: 133268
# First few doc_ids: ['93057', '58452', '529433']
# Processing qid: 95352
# First few doc_ids: ['546635', '639094', '634635']
# Processing qid: 23365
# First few doc_ids: ['87599', '87597', '170881']
# Processing qid: 64581
# First few doc_ids: ['64874', '136103', '153911']
# Processing qid: 137496
# First few doc_ids: ['34863', '11397', '118158']
# Processing qid: 18298
# First few doc_ids: ['81932', '227882', '104113']
# Processing qid: 87297
# First few doc_ids: ['507174', '36091', '636780']
# Processing qid: 68220
# First few doc_ids: ['78037', '77122', '65317']
# Processing qid: 76768
# First few doc_ids: ['1330', '30613', '123885']
# Processing qid: 28563
# First few doc_ids: ['156352', '99598', '147745']
# Processing qid: 127499
# First few doc_ids: ['252765', '145295', '143940']
# Processing qid: 20882
# First few doc_ids: ['44656', '44657', '78820']
# Processing qid: 102613
# First few doc_ids: ['39536', '58153', '90923']
# Processing qid: 31196
# First few doc_ids: ['96378', '85050', '180408']
# Processing qid: 133246
# First few doc_ids: ['144876', '63755', '208278']
# Processing qid: 28349
# First few doc_ids: ['228904', '145846', '100306']
# Processing qid: 175053
# First few doc_ids: ['101683', '47216', '47230']
# Processing qid: 12956
# First few doc_ids: ['236567', '45618', '251216']
# Processing qid: 132750
# First few doc_ids: ['558357', '220633', '144732']
# Processing qid: 94868
# First few doc_ids: ['105209', '14238', '90710']
# Processing qid: 103112
# First few doc_ids: ['252086', '223204', '97262']
# Processing qid: 136022
# First few doc_ids: ['135452', '49475', '66246']
# Processing qid: 13725
# First few doc_ids: ['76779', '16878', '74806']
# Processing qid: 31470
# First few doc_ids: ['21739', '82640', '157009']
# Processing qid: 45522
# First few doc_ids: ['181702', '80169', '121905']
# Processing qid: 82697
# First few doc_ids: ['132772', '132773', '52471']
# Processing qid: 88069
# First few doc_ids: ['16459', '155151', '85233']
# Processing qid: 36339
# First few doc_ids: ['102154', '102155', '145725']
# Processing qid: 80283
# First few doc_ids: ['97576', '470359', '21495']
# Processing qid: 77094
# First few doc_ids: ['10899', '10948', '990']
# Processing qid: 92165
# First few doc_ids: ['164744', '37989', '152703']
# Processing qid: 119130
# First few doc_ids: ['161926', '67370', '167244']
# Processing qid: 105528
# First few doc_ids: ['112208', '64052', '14889']
# Processing qid: 112222
# First few doc_ids: ['45022', '66544', '45012']
# Processing qid: 155254
# First few doc_ids: ['228185', '141444', '92948']
# Processing qid: 133062
# First few doc_ids: ['132670', '620356', '39522']
# Processing qid: 87004
# First few doc_ids: ['158948', '223911', '158947']
# Processing qid: 143307
# First few doc_ids: ['47072', '16358', '9556']
# Processing qid: 133461
# First few doc_ids: ['154286', '211594', '190381']
# Processing qid: 125836
# First few doc_ids: ['205413', '194229', '91493']
# Processing qid: 69774
# First few doc_ids: ['225783', '177727', '158782']
# Processing qid: 95595
# First few doc_ids: ['568978', '36218', '483914']
# Processing qid: 132350
# First few doc_ids: ['209695', '592012', '119783']
# Processing qid: 141846
# First few doc_ids: ['220291', '78232', '81787']
# Processing qid: 79837
# First few doc_ids: ['46570', '81402', '340']
# Processing qid: 42751
# First few doc_ids: ['138890', '162292', '216375']
# Processing qid: 11821
# First few doc_ids: ['156492', '67840', '245967']
# Processing qid: 136305
# First few doc_ids: ['214112', '151155', '26115']
# Processing qid: 140446
# First few doc_ids: ['218723', '218722', '260220']
# Processing qid: 148382
# First few doc_ids: ['19074', '184792', '19073']
# Processing qid: 145139
# First few doc_ids: ['86830', '212366', '142988']
# Processing qid: 27518
# First few doc_ids: ['61423', '17653', '163683']
# Processing qid: 109153
# First few doc_ids: ['29930', '110362', '515920']
# Processing qid: 85518
# First few doc_ids: ['148180', '136818', '148181']
# Processing qid: 88118
# First few doc_ids: ['128306', '14213', '31888']
# Processing qid: 60163
# First few doc_ids: ['65514', '75839', '61526']
# Processing qid: 154799
# First few doc_ids: ['47264', '232448', '36465']
# Processing qid: 10082
# First few doc_ids: ['474349', '69507', '80699']
# Processing qid: 15873
# First few doc_ids: ['230464', '94861', '77727']
# Processing qid: 6799
# First few doc_ids: ['69049', '149243', '249727']
# Processing qid: 130246
# First few doc_ids: ['64241', '535013', '60288']
# Processing qid: 29963
# First few doc_ids: ['114628', '87146', '154130']
# Processing qid: 51562
# First few doc_ids: ['119223', '249035', '3439']
# Processing qid: 81847
# First few doc_ids: ['22321', '152819', '589455']
# Processing qid: 17320
# First few doc_ids: ['80841', '175860', '10068']
# Processing qid: 59205
# First few doc_ids: ['64697', '66531', '204459']
# Processing qid: 67593
# First few doc_ids: ['42953', '51938', '446584']
# Processing qid: 153152
# First few doc_ids: ['89540', '14869', '14857']
# Processing qid: 29495
# First few doc_ids: ['104548', '55726', '145996']
# Processing qid: 20050
# First few doc_ids: ['33038', '83897', '27287']
# Processing qid: 99736
# First few doc_ids: ['173231', '642355', '101247']
# Processing qid: 129953
# First few doc_ids: ['157238', '18763', '87129']
# Processing qid: 131718
# First few doc_ids: ['163430', '258954', '188699']
# Processing qid: 81217
# First few doc_ids: ['50736', '89960', '174823']
# Processing qid: 88983
# First few doc_ids: ['199509', '206671', '201696']
# Processing qid: 108812
# First few doc_ids: ['183336', '80972', '496396']
# Processing qid: 157402
# First few doc_ids: ['198442', '237701', '45485']
# Processing qid: 16279
# First few doc_ids: ['37516', '37511', '37506']
# Processing qid: 108123
# First few doc_ids: ['182578', '237167', '472975']
# Processing qid: 27597
# First few doc_ids: ['183835', '241583', '196412']
# Processing qid: 86089
# First few doc_ids: ['62083', '83131', '83133']
# Processing qid: 67297
# First few doc_ids: ['26406', '44818', '195886']
# Processing qid: 39240
# First few doc_ids: ['105431', '207254', '109316']
# Processing qid: 166574
# First few doc_ids: ['117438', '630348', '117437']
# Processing qid: 40393
# First few doc_ids: ['16942', '6732', '79821']
# Processing qid: 117866
# First few doc_ids: ['112247', '187136', '72953']
# Processing qid: 123654
# First few doc_ids: ['72361', '166341', '237535']
# Processing qid: 17686
# First few doc_ids: ['89228', '82821', '163101']
# Processing qid: 81019
# First few doc_ids: ['62300', '250526', '583766']
# Processing qid: 102089
# First few doc_ids: ['67836', '72446', '40476']
# Processing qid: 21127
# First few doc_ids: ['72578', '85103', '47077']
# Processing qid: 95095
# First few doc_ids: ['259360', '93214', '133907']
# Processing qid: 107340
# First few doc_ids: ['101588', '101589', '133232']
# Processing qid: 145843
# First few doc_ids: ['40964', '204459', '62333']
# Processing qid: 160538
# First few doc_ids: ['88859', '40437', '602130']
# Processing qid: 104054
# First few doc_ids: ['105756', '124672', '19246']
# Processing qid: 155488
# First few doc_ids: ['20697', '38676', '637785']
# Processing qid: 126855
# First few doc_ids: ['203555', '94945', '79781']
# Processing qid: 137078
# First few doc_ids: ['6753', '6754', '40968']
# Processing qid: 70327
# First few doc_ids: ['1688', '84167', '72083']
# Processing qid: 124706
# First few doc_ids: ['18206', '161569', '639870']
# Processing qid: 38056
# First few doc_ids: ['59513', '10581', '59515']
# Processing qid: 31811
# First few doc_ids: ['64551', '37185', '97053']
# Processing qid: 98508
# First few doc_ids: ['255202', '23749', '89826']
# Processing qid: 30412
# First few doc_ids: ['86612', '86613', '183225']
# Processing qid: 140798
# First few doc_ids: ['50772', '18184', '552101']
# Processing qid: 38414
# First few doc_ids: ['37635', '104501', '104502']
# Processing qid: 5170
# First few doc_ids: ['4627', '229158', '4625']
# Processing qid: 22400
# First few doc_ids: ['86509', '71855', '71854']
# Processing qid: 83187
# First few doc_ids: ['484316', '154673', '613633']
# Processing qid: 58560
# First few doc_ids: ['1831', '64688', '56201']
# Processing qid: 68982
# First few doc_ids: ['101310', '81098', '64345']
# Processing qid: 4681
# First few doc_ids: ['131664', '133916', '85945']
# Processing qid: 96827
# First few doc_ids: ['530261', '113022', '583502']
# Processing qid: 11541
# First few doc_ids: ['74331', '187334', '573349']
# Processing qid: 12769
# First few doc_ids: ['14919', '14920', '14906']
# Processing qid: 138789
# First few doc_ids: ['216877', '65790', '79736']
# Processing qid: 37133
# First few doc_ids: ['512583', '512602', '611062']
# Processing qid: 149434
# First few doc_ids: ['253921', '127055', '117154']
# Processing qid: 4018
# First few doc_ids: ['55686', '463235', '533738']
# Processing qid: 39513
# First few doc_ids: ['81957', '494947', '246853']
# Processing qid: 67849
# First few doc_ids: ['137452', '137451', '12723']
# Processing qid: 155045
# First few doc_ids: ['91240', '154429', '116293']
# Processing qid: 44393
# First few doc_ids: ['107502', '238650', '84068']
# Processing qid: 23109
# First few doc_ids: ['153477', '188859', '116198']
# Processing qid: 69327
# First few doc_ids: ['208977', '11976', '39777']
# Processing qid: 19044
# First few doc_ids: ['36191', '538327', '555312']
# Processing qid: 97527
# First few doc_ids: ['142357', '485635', '464640']
# Processing qid: 11469
# First few doc_ids: ['74251', '473813', '644507']
# Processing qid: 127419
# First few doc_ids: ['161573', '218061', '62043']
# Processing qid: 82068
# First few doc_ids: ['78022', '66888', '77509']
# Processing qid: 99693
# First few doc_ids: ['111231', '14198', '49113']
# Processing qid: 43124
# First few doc_ids: ['109766', '16365', '130845']
# Processing qid: 40888
# First few doc_ids: ['31971', '50523', '80840']
# Processing qid: 69351
# First few doc_ids: ['140893', '122697', '80670']
# Processing qid: 18693
# First few doc_ids: ['82368', '6856', '5687']
# Processing qid: 78944
# First few doc_ids: ['113538', '174204', '149919']
# Processing qid: 57847
# First few doc_ids: ['18459', '14212', '31085']
# Processing qid: 15998
# First few doc_ids: ['79079', '135851', '67675']
# Processing qid: 124612
# First few doc_ids: ['52827', '177353', '40896']
# Processing qid: 135208
# First few doc_ids: ['212893', '14265', '129156']
# Processing qid: 70092
# First few doc_ids: ['507581', '139981', '208546']
# Processing qid: 134412
# First few doc_ids: ['56958', '36725', '93531']
# Processing qid: 108077
# First few doc_ids: ['182529', '182530', '255530']
# Processing qid: 104159
# First few doc_ids: ['21151', '580978', '21178']
# Processing qid: 9583
# First few doc_ids: ['128447', '108756', '108441']
# Processing qid: 129335
# First few doc_ids: ['50564', '132849', '99156']
# Processing qid: 46738
# First few doc_ids: ['75839', '69498', '65514']
# Processing qid: 58123
# First few doc_ids: ['35426', '20597', '126564']
# Processing qid: 42627
# First few doc_ids: ['109205', '206032', '30664']
# Processing qid: 107025
# First few doc_ids: ['531566', '592779', '503954']
# Processing qid: 118263
# First few doc_ids: ['18787', '18785', '10929']
# Processing qid: 114575
# First few doc_ids: ['85862', '96481', '245318']
# Processing qid: 6740
# First few doc_ids: ['73335', '39866', '157386']
# Processing qid: 73593
# First few doc_ids: ['67853', '193137', '122047']
# Processing qid: 70854
# First few doc_ids: ['232247', '17514', '70964']
# Processing qid: 100598
# First few doc_ids: ['630373', '218699', '601520']
# Processing qid: 150515
# First few doc_ids: ['116828', '50086', '517521']
# Processing qid: 119173
# First few doc_ids: ['147202', '93324', '67112']
# Processing qid: 49729
# First few doc_ids: ['40003', '56317', '134750']
# Processing qid: 160775
# First few doc_ids: ['17827', '603217', '17828']
# Processing qid: 66927
# First few doc_ids: ['98768', '61784', '81280']
# Processing qid: 36894
# First few doc_ids: ['23439', '54773', '71196']
# Processing qid: 64617
# First few doc_ids: ['178773', '198621', '223060']
# Processing qid: 15713
# First few doc_ids: ['56341', '79037', '12259']
# Processing qid: 87044
# First few doc_ids: ['15427', '170254', '8607']
# Processing qid: 92376
# First few doc_ids: ['195686', '66540', '140833']
# Processing qid: 69605
# First few doc_ids: ['139430', '31676', '197156']
# Processing qid: 39384
# First few doc_ids: ['105590', '217416', '184366']
# Processing qid: 63790
# First few doc_ids: ['89470', '627480', '50760']
# Processing qid: 164061
# First few doc_ids: ['71787', '180132', '644583']
# Processing qid: 158670
# First few doc_ids: ['62414', '136395', '55044']
# Processing qid: 115243
# First few doc_ids: ['122444', '63522', '30809']
# Processing qid: 41603
# First few doc_ids: ['15606', '79780', '58206']
# Processing qid: 22718
# First few doc_ids: ['86869', '159309', '151214']
# Processing qid: 123450
# First few doc_ids: ['10647', '94726', '10719']
# Processing qid: 94790
# First few doc_ids: ['87799', '78076', '17622']
# Processing qid: 83456
# First few doc_ids: ['157254', '18339', '66784']
# Processing qid: 109691
# First few doc_ids: ['631042', '92329', '629371']
# Processing qid: 99038
# First few doc_ids: ['65154', '58243', '86542']
# Processing qid: 72883
# First few doc_ids: ['174848', '506472', '91392']
# Processing qid: 84363
# First few doc_ids: ['41321', '56214', '41335']
# Processing qid: 166322
# First few doc_ids: ['243047', '5802', '93927']
# Processing qid: 148211
# First few doc_ids: ['100490', '65154', '99180']
# Processing qid: 27689
# First few doc_ids: ['207202', '138371', '78336']
# Processing qid: 90597
# First few doc_ids: ['39243', '175768', '47639']
# Processing qid: 14380
# First few doc_ids: ['70113', '253866', '49804']
# Processing qid: 22798
# First few doc_ids: ['31468', '31469', '18295']
# Processing qid: 119856
# First few doc_ids: ['55668', '257531', '55664']
# Processing qid: 92563
# First few doc_ids: ['97331', '75248', '40896']
# Processing qid: 150706
# First few doc_ids: ['67185', '207484', '67184']
# Processing qid: 19766
# First few doc_ids: ['80965', '111667', '565404']
# Processing qid: 80224
# First few doc_ids: ['151360', '24952', '229857']
# Processing qid: 139990
# First few doc_ids: ['218224', '16385', '47077']
# Processing qid: 106719
# First few doc_ids: ['15673', '54896', '73503']
# Processing qid: 57817
# First few doc_ids: ['558773', '126229', '3970']
# Processing qid: 140197
# First few doc_ids: ['218453', '205714', '26400']
# Processing qid: 2651
# First few doc_ids: ['64391', '126561', '105551']
# Processing qid: 137598
# First few doc_ids: ['22704', '23757', '568819']
# Processing qid: 41488
# First few doc_ids: ['107922', '107921', '467098']
# Processing qid: 126113
# First few doc_ids: ['61364', '547316', '567168']
# Processing qid: 168817
# First few doc_ids: ['607832', '561319', '17036']
# Processing qid: 122284
# First few doc_ids: ['196938', '104449', '145090']
# Processing qid: 59039
# First few doc_ids: ['127596', '63761', '251565']
# Processing qid: 147451
# First few doc_ids: ['25201', '159846', '82597']
# Processing qid: 61556
# First few doc_ids: ['13765', '13764', '53492']
# Processing qid: 104796
# First few doc_ids: ['173474', '68629', '531991']
# Processing qid: 152337
# First few doc_ids: ['2512', '39755', '138018']
# Processing qid: 8792
# First few doc_ids: ['71275', '527401', '229784']
# Processing qid: 45811
# First few doc_ids: ['61900', '57256', '67372']
# Processing qid: 100118
# First few doc_ids: ['9373', '484544', '628132']
# Processing qid: 154358
# First few doc_ids: ['208562', '72033', '525460']
# Processing qid: 112282
# First few doc_ids: ['137083', '135189', '115804']
# Processing qid: 134831
# First few doc_ids: ['50566', '249153', '65863']
# Processing qid: 158494
# First few doc_ids: ['189733', '50657', '534697']
# Processing qid: 45479
# First few doc_ids: ['232498', '184066', '30450']
# Processing qid: 50202
# First few doc_ids: ['117660', '247817', '117659']
# Processing qid: 86913
# First few doc_ids: ['26475', '46045', '219477']
# Processing qid: 159678
# First few doc_ids: ['139882', '62023', '216846']
# Processing qid: 58734
# First few doc_ids: ['465309', '77812', '181164']
# Processing qid: 57956
# First few doc_ids: ['489165', '476712', '126384']
# Processing qid: 105229
# First few doc_ids: ['89289', '164073', '88887']
# Processing qid: 39887
# First few doc_ids: ['25490', '98444', '2863']
# Processing qid: 18857
# First few doc_ids: ['31479', '532101', '153767']
# Processing qid: 139528
# First few doc_ids: ['72282', '140105', '244483']
# Processing qid: 76460
# First few doc_ids: ['147168', '38357', '38361']
# Processing qid: 78873
# First few doc_ids: ['63807', '53492', '195525']
# Processing qid: 10429
# First few doc_ids: ['4526', '47465', '56758']
# Processing qid: 87442
# First few doc_ids: ['159445', '55840', '159444']
# Processing qid: 155919
# First few doc_ids: ['180413', '236019', '65687']
# Processing qid: 177596
# First few doc_ids: ['42820', '114761', '66860']
# Processing qid: 40522
# First few doc_ids: ['64921', '49705', '141701']
# Processing qid: 36885
# First few doc_ids: ['59281', '155831', '142076']
# Processing qid: 15132
# First few doc_ids: ['221328', '53084', '83601']
# Processing qid: 44436
# First few doc_ids: ['111244', '111245', '70309']
# Processing qid: 17883
# First few doc_ids: ['67185', '81472', '81474']
# Processing qid: 164812
# First few doc_ids: ['24461', '62075', '155744']
# Processing qid: 135015
# First few doc_ids: ['129615', '142986', '185230']
# Processing qid: 62387
# First few doc_ids: ['131342', '34546', '61929']
# Processing qid: 115185
# First few doc_ids: ['190478', '126923', '89073']
# Processing qid: 13242
# First few doc_ids: ['33906', '592026', '33908']
# Processing qid: 111690
# First few doc_ids: ['75847', '100606', '75848']
# Processing qid: 104743
# First few doc_ids: ['56467', '49632', '193205']
# Processing qid: 47864
# First few doc_ids: ['45019', '77718', '201393']
# Processing qid: 167181
# First few doc_ids: ['222509', '70067', '71982']
# Processing qid: 174451
# First few doc_ids: ['69511', '77023', '163758']
# Processing qid: 135797
# First few doc_ids: ['23250', '511324', '104304']
# Processing qid: 8596
# First few doc_ids: ['244985', '71055', '483884']
# Processing qid: 63741
# First few doc_ids: ['29797', '195981', '245419']
# Processing qid: 81634
# First few doc_ids: ['152932', '76468', '76470']
# Processing qid: 33017
# First few doc_ids: ['63072', '132567', '10441']
# Processing qid: 100775
# First few doc_ids: ['49743', '96516', '90254']
# Processing qid: 12008
# First few doc_ids: ['74869', '163267', '32593']
# Processing qid: 10157
# First few doc_ids: ['52034', '13242', '42521']
# Processing qid: 44834
# First few doc_ids: ['111689', '76284', '259086']
# Processing qid: 28240
# First few doc_ids: ['86198', '43877', '5706']
# Processing qid: 28554
# First few doc_ids: ['39926', '39932', '93434']
# Processing qid: 13504
# First few doc_ids: ['96678', '65911', '15217']
# Processing qid: 89342
# First few doc_ids: ['38012', '50454', '489762']
# Processing qid: 56712
# First few doc_ids: ['124997', '31780', '488266']
# Processing qid: 12062
# First few doc_ids: ['58452', '451294', '497918']
# Processing qid: 80866
# First few doc_ids: ['79169', '147933', '143219']
# Processing qid: 114009
# First few doc_ids: ['189155', '206712', '246483']
# Processing qid: 145722
# First few doc_ids: ['182147', '147788', '33604']
# Processing qid: 130067
# First few doc_ids: ['148106', '39134', '83353']
# Processing qid: 30775
# First few doc_ids: ['549380', '107309', '36156']
# Processing qid: 124729
# First few doc_ids: ['201175', '618548', '40309']
# Processing qid: 22379
# First few doc_ids: ['16091', '80876', '6204']
# Processing qid: 108417
# First few doc_ids: ['27808', '30997', '114842']
# Processing qid: 49014
# First few doc_ids: ['116360', '196157', '100049']
# Processing qid: 106484
# First few doc_ids: ['180733', '513207', '16165']
# Processing qid: 25192
# First few doc_ids: ['30867', '567224', '463001']
# Processing qid: 76279
# First few doc_ids: ['182069', '22498', '146968']
# Processing qid: 32642
# First few doc_ids: ['134381', '76333', '14714']
# Processing qid: 99209
# First few doc_ids: ['172632', '603373', '95729']
# Processing qid: 115386
# First few doc_ids: ['22438', '41082', '99279']
# Processing qid: 74908
# First few doc_ids: ['40266', '12500', '455432']
# Processing qid: 37446
# First few doc_ids: ['99711', '99709', '29906']
# Processing qid: 54342
# First few doc_ids: ['122354', '110724', '531668']
# Processing qid: 137816
# First few doc_ids: ['107112', '62982', '89042']
# Processing qid: 8466
# First few doc_ids: ['68867', '37213', '491278']
# Processing qid: 128309
# First few doc_ids: ['205183', '205182', '16656']
# Processing qid: 86463
# First few doc_ids: ['46821', '31022', '158344']
# Processing qid: 97854
# First few doc_ids: ['139883', '106121', '95721']
# Processing qid: 94440
# First few doc_ids: ['167284', '14589', '14621']
# Processing qid: 48927
# First few doc_ids: ['186697', '75744', '20131']
# Processing qid: 63615
# First few doc_ids: ['80856', '33090', '521582']
# Processing qid: 85790
# First few doc_ids: ['58604', '58457', '194318']
# Processing qid: 113304
# First few doc_ids: ['133230', '31821', '217353']
# Processing qid: 21416
# First few doc_ids: ['623615', '560593', '559665']
# Processing qid: 113470
# First few doc_ids: ['188554', '627281', '90882']
# Processing qid: 4572
# First few doc_ids: ['66557', '66064', '113914']
# Processing qid: 76308
# First few doc_ids: ['148055', '575347', '472576']
# Processing qid: 163405
# First few doc_ids: ['169414', '71765', '169413']
# Processing qid: 155414
# First few doc_ids: ['70727', '61615', '113856']
# Processing qid: 38676
# First few doc_ids: ['64370', '608026', '126827']
# Processing qid: 152764
# First few doc_ids: ['61283', '50862', '154392']
# Processing qid: 111567
# First few doc_ids: ['37547', '221509', '93882']
# Processing qid: 137489
# First few doc_ids: ['215431', '185160', '81446']
# Processing qid: 106695
# First few doc_ids: ['446578', '41593', '52340']
# Processing qid: 173816
# First few doc_ids: ['170840', '58777', '63233']
# Processing qid: 67899
# First few doc_ids: ['56253', '70983', '93272']
# Processing qid: 155185
# First few doc_ids: ['235192', '238747', '247868']
# Processing qid: 90401
# First few doc_ids: ['162776', '72524', '73463']
# Processing qid: 170430
# First few doc_ids: ['54639', '8120', '593765']
# Processing qid: 58927
# First few doc_ids: ['27784', '151018', '8342']
# Processing qid: 74052
# First few doc_ids: ['83094', '144448', '81778']
# Processing qid: 60367
# First few doc_ids: ['129083', '108339', '72677']
# Processing qid: 13819
# First few doc_ids: ['104443', '132034', '82953']
# Processing qid: 18738
# First few doc_ids: ['80653', '123642', '21214']
# Processing qid: 47477
# First few doc_ids: ['74080', '78975', '114644']
# Processing qid: 24243
# First few doc_ids: ['44735', '645064', '569390']
# Processing qid: 45780
# First few doc_ids: ['29690', '494346', '28290']
# Processing qid: 152878
# First few doc_ids: ['87723', '144055', '85019']
# Processing qid: 113917
# First few doc_ids: ['82573', '130648', '33583']
# Processing qid: 62064
# First few doc_ids: ['130987', '51826', '177982']
# Processing qid: 130597
# First few doc_ids: ['207749', '34333', '48149']
# Processing qid: 104952
# First few doc_ids: ['111482', '179642', '206006']
# Processing qid: 34496
# First few doc_ids: ['135140', '175697', '77487']
# Processing qid: 85508
# First few doc_ids: ['566213', '605782', '566216']
# Processing qid: 57278
# First few doc_ids: ['236543', '85277', '527049']
# Processing qid: 3104
# First few doc_ids: ['64883', '217538', '217754']
# Processing qid: 133607
# First few doc_ids: ['75206', '122174', '525217']
# Processing qid: 119567
# First few doc_ids: ['30853', '60428', '71934']
# Processing qid: 118115
# First few doc_ids: ['141002', '91446', '210949']
# Processing qid: 17197
# First few doc_ids: ['609774', '597075', '597037']
# Processing qid: 56462
# First few doc_ids: ['118894', '124720', '40065']
# Processing qid: 52131
# First few doc_ids: ['145718', '119859', '44338']
# Processing qid: 15119
# First few doc_ids: ['78355', '78354', '452858']
# Processing qid: 119609
# First few doc_ids: ['17155', '60264', '44861']
# Processing qid: 53024
# First few doc_ids: ['108328', '19805', '38200']
# Processing qid: 59813
# First few doc_ids: ['140257', '101722', '184177']
# Processing qid: 112538
# First few doc_ids: ['66844', '252488', '19367']
# Processing qid: 139705
# First few doc_ids: ['129255', '163490', '8266']
# Processing qid: 81103
# First few doc_ids: ['163908', '58735', '58747']
# Processing qid: 90059
# First few doc_ids: ['4519', '51500', '51496']
# Processing qid: 155707
# First few doc_ids: ['96519', '96520', '96521']
# Processing qid: 83155
# First few doc_ids: ['154638', '191971', '248392']
# Processing qid: 42400
# First few doc_ids: ['108312', '47643', '47644']
# Processing qid: 101650
# First few doc_ids: ['173037', '65924', '63704']
# Processing qid: 54901
# First few doc_ids: ['75690', '56958', '24919']
# Processing qid: 82501
# First few doc_ids: ['153906', '98991', '62052']
# Processing qid: 95648
# First few doc_ids: ['42979', '245340', '95647']
# Processing qid: 134982
# First few doc_ids: ['76908', '44953', '44946']
# Processing qid: 17937
# First few doc_ids: ['70448', '210819', '103905']
# Processing qid: 8665
# First few doc_ids: ['55981', '52009', '42479']
# Processing qid: 121401
# First few doc_ids: ['89668', '69442', '593866']
# Processing qid: 83913
# First few doc_ids: ['97994', '79208', '46289']
# Processing qid: 33080
# First few doc_ids: ['50525', '211660', '211661']
# Processing qid: 104561
# First few doc_ids: ['59513', '10581', '59515']
# Processing qid: 128470
# First few doc_ids: ['67530', '237678', '224527']
# Processing qid: 135940
# First few doc_ids: ['213702', '245125', '63522']
# Processing qid: 163365
# First few doc_ids: ['10513', '67727', '95832']
# Processing qid: 132008
# First few doc_ids: ['92612', '239791', '27830']
# Processing qid: 59906
# First few doc_ids: ['107339', '46497', '80727']
# Processing qid: 77737
# First few doc_ids: ['64806', '87002', '203643']
# Processing qid: 71428
# First few doc_ids: ['37441', '73874', '150930']
# Processing qid: 112111
# First few doc_ids: ['102777', '8591', '224282']
# Processing qid: 128592
# First few doc_ids: ['93115', '157715', '204848']
# Processing qid: 121628
# First few doc_ids: ['72229', '23791', '220089']
# Processing qid: 77095
# First few doc_ids: ['10949', '43141', '59773']
# Processing qid: 2323
# First few doc_ids: ['222223', '476497', '639367']
# Processing qid: 150578
# First few doc_ids: ['201702', '73956', '75204']
# Processing qid: 117565
# First few doc_ids: ['62478', '170908', '62476']
# Processing qid: 141490
# First few doc_ids: ['81310', '211097', '194570']
# Processing qid: 32837
# First few doc_ids: ['19462', '80756', '19464']
# Processing qid: 60991
# First few doc_ids: ['34719', '104136', '73475']
# Processing qid: 31161
# First few doc_ids: ['41277', '7423', '125410']
# Processing qid: 80660
# First few doc_ids: ['81684', '164112', '160555']
# Processing qid: 3504
# First few doc_ids: ['148788', '195267', '63878']
# Processing qid: 127271
# First few doc_ids: ['124233', '101105', '101106']
# Processing qid: 84472
# First few doc_ids: ['156127', '75848', '75847']
# Processing qid: 51528
# First few doc_ids: ['89053', '47614', '62508']
# Processing qid: 30004
# First few doc_ids: ['95056', '126079', '95057']
# Processing qid: 166019
# First few doc_ids: ['247355', '53787', '104648']
# Processing qid: 111790
# First few doc_ids: ['144972', '99742', '3994']
# Processing qid: 90068
# First few doc_ids: ['42335', '114097', '42332']
# Processing qid: 50817
# First few doc_ids: ['46234', '46235', '167177']
# Processing qid: 107377
# First few doc_ids: ['491550', '615371', '635564']
# Processing qid: 38185
# First few doc_ids: ['204849', '41346', '104244']
# Processing qid: 127183
# First few doc_ids: ['203929', '159263', '62548']
# Processing qid: 145775
# First few doc_ids: ['224705', '114183', '21188']
# Processing qid: 127026
# First few doc_ids: ['32162', '186068', '254151']
# Processing qid: 107775
# First few doc_ids: ['182183', '65473', '74068']
# Processing qid: 2489
# First few doc_ids: ['3157', '3159', '72542']
# Processing qid: 135499
# First few doc_ids: ['180990', '70100', '254129']
# Processing qid: 126645
# First few doc_ids: ['2172', '2161', '24084']
# Processing qid: 57972
# First few doc_ids: ['219180', '104896', '549092']
# Processing qid: 41546
# First few doc_ids: ['107987', '563651', '104524']
# Processing qid: 79794
# First few doc_ids: ['75261', '206671', '150879']
# Processing qid: 73863
# First few doc_ids: ['251865', '13538', '13530']
# Processing qid: 94218
# First few doc_ids: ['43123', '61213', '69332']
# Processing qid: 101032
# First few doc_ids: ['174651', '8797', '8794']
# Processing qid: 25061
# First few doc_ids: ['89163', '78505', '143032']
# Processing qid: 105018
# First few doc_ids: ['43464', '99815', '79914']
# Processing qid: 35449
# First few doc_ids: ['7893', '118649', '179378']
# Processing qid: 109527
# First few doc_ids: ['69498', '75839', '594157']
# Processing qid: 24669
# First few doc_ids: ['567058', '58651', '46382']
# Processing qid: 60818
# First few doc_ids: ['568265', '506800', '485240']
# Processing qid: 54753
# First few doc_ids: ['256608', '97613', '54551']
# Processing qid: 140734
# First few doc_ids: ['70585', '175393', '142815']
# Processing qid: 72672
# First few doc_ids: ['83819', '25237', '510403']
# Processing qid: 96650
# First few doc_ids: ['65023', '62142', '208483']
# Processing qid: 12544
# First few doc_ids: ['181418', '71720', '188427']
# Processing qid: 88681
# First few doc_ids: ['462123', '166606', '185696']
# Processing qid: 4243
# First few doc_ids: ['106542', '73743', '493502']
# Processing qid: 154508
# First few doc_ids: ['50661', '526148', '50546']
# Processing qid: 86258
# First few doc_ids: ['107100', '132135', '484302']
# Processing qid: 107335
# First few doc_ids: ['589815', '146753', '75257']
# Processing qid: 137936
# First few doc_ids: ['84041', '195308', '133705']
# Processing qid: 17455
# First few doc_ids: ['123499', '636150', '78278']
# Processing qid: 11403
# First few doc_ids: ['51063', '227282', '205496']
# Processing qid: 126624
# First few doc_ids: ['35003', '16090', '35002']
# Processing qid: 46938
# First few doc_ids: ['205890', '61649', '478024']
# Processing qid: 99692
# First few doc_ids: ['173176', '35026', '488298']
# Processing qid: 8077
# First few doc_ids: ['70479', '114507', '91226']
# Processing qid: 87896
# First few doc_ids: ['159967', '140575', '134342']
# Processing qid: 114151
# First few doc_ids: ['251267', '230627', '491894']
# Processing qid: 62524
# First few doc_ids: ['50606', '625039', '84227']
# Processing qid: 50673
# First few doc_ids: ['64752', '206167', '118189']
# Processing qid: 117695
# First few doc_ids: ['195977', '166648', '622722']
# Processing qid: 21387
# First few doc_ids: ['8940', '8939', '101748']
# Processing qid: 97820
# First few doc_ids: ['213187', '138285', '84855']
# Processing qid: 44552
# First few doc_ids: ['111370', '111369', '198456']
# Processing qid: 94408
# First few doc_ids: ['564035', '514644', '570469']
# Processing qid: 47032
# First few doc_ids: ['114164', '106082', '127254']
# Processing qid: 117032
# First few doc_ids: ['147042', '114541', '249246']
# Processing qid: 101280
# First few doc_ids: ['174931', '74039', '97256']
# Processing qid: 57464
# First few doc_ids: ['58741', '58739', '58777']
# Processing qid: 48164
# First few doc_ids: ['10717', '205890', '61649']
# Processing qid: 161965
# First few doc_ids: ['72835', '217932', '55183']
# Processing qid: 159145
# First few doc_ids: ['502848', '534697', '37250']
# Processing qid: 109593
# First few doc_ids: ['142988', '86829', '73748']
# Processing qid: 17808
# First few doc_ids: ['639039', '448387', '631782']
# Processing qid: 62175
# First few doc_ids: ['1659', '131106', '128116']
# Processing qid: 10369
# First few doc_ids: ['620683', '38220', '596321']
# Processing qid: 83235
# First few doc_ids: ['545406', '470862', '627661']
# Processing qid: 94728
# First few doc_ids: ['435', '432', '7312']
# Processing qid: 35135
# First few doc_ids: ['100768', '100767', '624299']
# Processing qid: 131738
# First few doc_ids: ['123632', '71373', '191223']
# Processing qid: 53959
# First few doc_ids: ['580982', '84697', '54469']
# Processing qid: 57604
# First few doc_ids: ['11783', '22961', '482004']
# Processing qid: 156338
# First few doc_ids: ['117260', '68629', '133667']
# Processing qid: 37077
# First few doc_ids: ['209206', '140026', '147315']
# Processing qid: 13269
# First few doc_ids: ['76277', '32593', '58850']
# Processing qid: 71178
# First few doc_ids: ['33258', '144765', '33257']
# Processing qid: 137097
# First few doc_ids: ['22450', '41027', '167486']
# Processing qid: 105960
# First few doc_ids: ['77211', '103250', '39497']
# Processing qid: 99855
# First few doc_ids: ['442347', '632706', '625231']
# Processing qid: 135717
# First few doc_ids: ['17739', '176257', '42787']
# Processing qid: 32172
# First few doc_ids: ['97451', '97449', '97450']
# Processing qid: 162761
# First few doc_ids: ['49891', '49898', '533238']
# Processing qid: 86340
# First few doc_ids: ['26971', '6973', '493460']
# Processing qid: 112643
# First few doc_ids: ['2162', '2181', '24088']
# Processing qid: 99418
# First few doc_ids: ['172877', '253293', '80143']
# Processing qid: 25027
# First few doc_ids: ['200406', '11897', '89612']
# Processing qid: 157692
# First few doc_ids: ['589815', '625480', '8342']
# Processing qid: 119240
# First few doc_ids: ['486211', '625237', '486210']
# Processing qid: 29393
# First few doc_ids: ['37572', '37573', '487832']
# Processing qid: 119921
# First few doc_ids: ['195308', '135117', '133705']
# Processing qid: 68278
# First few doc_ids: ['209785', '137924', '137925']
# Processing qid: 33802
# First few doc_ids: ['70881', '22596', '208916']
# Processing qid: 122129
# First few doc_ids: ['529047', '493164', '14570']
# Processing qid: 24665
# First few doc_ids: ['89077', '58139', '58545']
# Processing qid: 88499
# First few doc_ids: ['160637', '218425', '182165']
# Processing qid: 161599
# First few doc_ids: ['245473', '103187', '83038']
# Processing qid: 146583
# First few doc_ids: ['49200', '183777', '62560']
# Processing qid: 91596
# First few doc_ids: ['164109', '621216', '135767']
# Processing qid: 120030
# First few doc_ids: ['166652', '70062', '580982']
# Processing qid: 93699
# First few doc_ids: ['166461', '89042', '89040']
# Processing qid: 80954
# First few doc_ids: ['8650', '52855', '64923']
# Processing qid: 96042
# First few doc_ids: ['30294', '50089', '615796']
# Processing qid: 13538
# First few doc_ids: ['83601', '221325', '160135']
# Processing qid: 28212
# First few doc_ids: ['93044', '23311', '111453']
# Processing qid: 108757
# First few doc_ids: ['155129', '59499', '251025']
# Processing qid: 39201
# First few doc_ids: ['144538', '67659', '94388']
# Processing qid: 164954
# First few doc_ids: ['63783', '149825', '92941']
# Processing qid: 53942
# First few doc_ids: ['121899', '489430', '10783']
# Processing qid: 61936
# First few doc_ids: ['237969', '14336', '14335']
# Processing qid: 74970
# First few doc_ids: ['226375', '145488', '203555']
# Processing qid: 143155
# First few doc_ids: ['221772', '259467', '259468']
# Processing qid: 19978
# First few doc_ids: ['629446', '251081', '78751']
# Processing qid: 111858
# First few doc_ids: ['186762', '161312', '165761']
# Processing qid: 110167
# First few doc_ids: ['19313', '70445', '52666']
# Processing qid: 152896
# First few doc_ids: ['152609', '84596', '117485']
# Processing qid: 151995
# First few doc_ids: ['231629', '231630', '24406']
# Processing qid: 116138
# First few doc_ids: ['208544', '210050', '191528']
# Processing qid: 81083
# First few doc_ids: ['129420', '53723', '461101']
# Processing qid: 63616
# First few doc_ids: ['201220', '592694', '85960']
# Processing qid: 137391
# First few doc_ids: ['224002', '143622', '170733']
# Processing qid: 119147
# First few doc_ids: ['152215', '94795', '197285']
# Processing qid: 107920
# First few doc_ids: ['620319', '182345', '574887']
# Processing qid: 153017
# First few doc_ids: ['128707', '92634', '196656']
# Processing qid: 109250
# First few doc_ids: ['19279', '169691', '183834']
# Processing qid: 16542
# First few doc_ids: ['79981', '105254', '523651']
# Processing qid: 119490
# First few doc_ids: ['80729', '14907', '167452']
# Processing qid: 44067
# First few doc_ids: ['65110', '50239', '111699']
# Processing qid: 116323
# First few doc_ids: ['184409', '67583', '88895']
# Processing qid: 48792
# First few doc_ids: ['474349', '152227', '110310']
# Processing qid: 55568
# First few doc_ids: ['65263', '106441', '44060']
# Processing qid: 5718
# First few doc_ids: ['61860', '68727', '68728']
# Processing qid: 5336
# First few doc_ids: ['229112', '13748', '13755']
# Processing qid: 96005
# First few doc_ids: ['185339', '66654', '139372']
# Processing qid: 90288
# First few doc_ids: ['16922', '97188', '97187']
# Processing qid: 45391
# First few doc_ids: ['112321', '19366', '20746']
# Processing qid: 17557
# First few doc_ids: ['81114', '33604', '628586']
# Processing qid: 152971
# First few doc_ids: ['88420', '62530', '61423']
# Processing qid: 9495
# First few doc_ids: ['98156', '178886', '145761']
# Processing qid: 13270
# First few doc_ids: ['76278', '259386', '124432']
# Processing qid: 8776
# First few doc_ids: ['592933', '559064', '469127']
# Processing qid: 21177
# First few doc_ids: ['61805', '102326', '41758']
# Processing qid: 126025
# First few doc_ids: ['17967', '138395', '84687']
# Processing qid: 111570
# First few doc_ids: ['63156', '90601', '158708']
# Processing qid: 64193
# First few doc_ids: ['130956', '106333', '134654']
# Processing qid: 110263
# First few doc_ids: ['468052', '468054', '533763']
# Processing qid: 131886
# First few doc_ids: ['9395', '197296', '116101']
# Processing qid: 48680
# First few doc_ids: ['101084', '78578', '50947']
# Processing qid: 150971
# First few doc_ids: ['53098', '53105', '53100']
# Processing qid: 37730
# First few doc_ids: ['103730', '204314', '76156']
# Processing qid: 99734
# First few doc_ids: ['173229', '181405', '216438']
# Processing qid: 108085
# First few doc_ids: ['182537', '213406', '14136']
# Processing qid: 122075
# First few doc_ids: ['235899', '182419', '64979']
# Processing qid: 159611
# First few doc_ids: ['16059', '140408', '22828']
# Processing qid: 159997
# First few doc_ids: ['43754', '5916', '62349']
# Processing qid: 163299
# First few doc_ids: ['119013', '203279', '252901']
# Processing qid: 126635
# First few doc_ids: ['1536', '6460', '8612']
# Processing qid: 115982
# First few doc_ids: ['213561', '213563', '181384']
# Processing qid: 178018
# First few doc_ids: ['42896', '5544', '97481']
# Processing qid: 61687
# First few doc_ids: ['130577', '480968', '42888']
# Processing qid: 116080
# First few doc_ids: ['495190', '550792', '462387']
# Processing qid: 122214
# First few doc_ids: ['117045', '103883', '25007']
# Processing qid: 101469
# First few doc_ids: ['82559', '117005', '128837']
# Processing qid: 83782
# First few doc_ids: ['193745', '20036', '155343']
# Processing qid: 70733
# First few doc_ids: ['168037', '83022', '140709']
# Processing qid: 68713
# First few doc_ids: ['74947', '234300', '148223']
# Processing qid: 54453
# First few doc_ids: ['54165', '54167', '54166']
# Processing qid: 69175
# First few doc_ids: ['189248', '42894', '163529']
# Processing qid: 101840
# First few doc_ids: ['90601', '66252', '63156']
# Processing qid: 2548
# First few doc_ids: ['64276', '64277', '583986']
# Processing qid: 5433
# First few doc_ids: ['67533', '3508', '3631']
# Processing qid: 34660
# First few doc_ids: ['593864', '132686', '133762']
# Processing qid: 67012
# First few doc_ids: ['19392', '67646', '121959']
# Processing qid: 48291
# First few doc_ids: ['115556', '52184', '121947']
# Processing qid: 37377
# First few doc_ids: ['103334', '103335', '4141']
# Processing qid: 130144
# First few doc_ids: ['17050', '232958', '126472']
# Processing qid: 19553
# First few doc_ids: ['231856', '587098', '74988']
# Processing qid: 139248
# First few doc_ids: ['10776', '217386', '582721']
# Processing qid: 135802
# First few doc_ids: ['27997', '85596', '213537']
# Processing qid: 10620
# First few doc_ids: ['73316', '185979', '162519']
# Processing qid: 147104
# First few doc_ids: ['226188', '232576', '50913']
# Processing qid: 86716
# First few doc_ids: ['528527', '46864', '577939']
# Processing qid: 35083
# First few doc_ids: ['82196', '100294', '149402']
# Processing qid: 119535
# First few doc_ids: ['14223', '4188', '196519']
# Processing qid: 126833
# First few doc_ids: ['21174', '211401', '161311']
# Processing qid: 77826
# First few doc_ids: ['37952', '37951', '173640']
# Processing qid: 62304
# First few doc_ids: ['71439', '71934', '118177']
# Processing qid: 111236
# First few doc_ids: ['59495', '59488', '72940']
# Processing qid: 144069
# First few doc_ids: ['68665', '68666', '68664']
# Processing qid: 138706
# First few doc_ids: ['537354', '617481', '442145']
# Processing qid: 166245
# First few doc_ids: ['629892', '233080', '18629']
# Processing qid: 135217
# First few doc_ids: ['90882', '101938', '40866']
# Processing qid: 97317
# First few doc_ids: ['79735', '168210', '24295']
# Processing qid: 90106
# First few doc_ids: ['64781', '155732', '121735']
# Processing qid: 131692
# First few doc_ids: ['108838', '193089', '97064']
# Processing qid: 139174
# First few doc_ids: ['596213', '485719', '615471']
# Processing qid: 140797
# First few doc_ids: ['55891', '48431', '48452']
# Processing qid: 90300
# First few doc_ids: ['88734', '141820', '532794']
# Processing qid: 98467
# First few doc_ids: ['241994', '153599', '80764']
# Processing qid: 152903
# First few doc_ids: ['10525', '534907', '138121']
# Processing qid: 123363
# First few doc_ids: ['5306', '5308', '5301']
# Processing qid: 150338
# First few doc_ids: ['156365', '9365', '526620']
# Processing qid: 54350
# First few doc_ids: ['208658', '115968', '63520']
# Processing qid: 142200
# First few doc_ids: ['58486', '58489', '208987']
# Processing qid: 86644
# First few doc_ids: ['114334', '157377', '147763']
# Processing qid: 179067
# First few doc_ids: ['39896', '24515', '17661']
# Processing qid: 44817
# First few doc_ids: ['137007', '88161', '26830']
# Processing qid: 125573
# First few doc_ids: ['611522', '641059', '515675']
# Processing qid: 164774
# First few doc_ids: ['65995', '7830', '7823']
# Processing qid: 78490
# First few doc_ids: ['64233', '91572', '74255']
# Processing qid: 60752
# First few doc_ids: ['154978', '59590', '64579']
# Processing qid: 136000
# First few doc_ids: ['240711', '173474', '586047']
# Processing qid: 14734
# First few doc_ids: ['83917', '93819', '635767']
# Processing qid: 12119
# First few doc_ids: ['147435', '82456', '45003']
# Processing qid: 155948
# First few doc_ids: ['633991', '544143', '550883']
# Processing qid: 10804
# First few doc_ids: ['86547', '153193', '158967']
# Processing qid: 35557
# First few doc_ids: ['101243', '101244', '18638']
# Processing qid: 84129
# First few doc_ids: ['80856', '64546', '460794']
# Processing qid: 24380
# First few doc_ids: ['88753', '173169', '74102']
# Processing qid: 45087
# First few doc_ids: ['111977', '183426', '9868']
# Processing qid: 30352
# First few doc_ids: ['38250', '95445', '38251']
# Processing qid: 156736
# First few doc_ids: ['62739', '161778', '88576']
# Processing qid: 144670
# First few doc_ids: ['115501', '223468', '115502']
# Processing qid: 69587
# First few doc_ids: ['139406', '614417', '65']
# Processing qid: 134739
# First few doc_ids: ['249751', '130956', '61879']
# Processing qid: 26999
# First few doc_ids: ['445933', '71345', '168879']
# Processing qid: 138918
# First few doc_ids: ['217023', '6359', '217024']
# Processing qid: 171849
# First few doc_ids: ['168429', '40842', '204126']
# Processing qid: 98987
# First few doc_ids: ['29100', '29101', '29113']
# Processing qid: 165289
# First few doc_ids: ['139691', '25004', '554556']
# Processing qid: 48102
# First few doc_ids: ['167', '168', '67658']
# Processing qid: 21662
# First few doc_ids: ['138849', '198671', '147841']
# Processing qid: 42857
# First few doc_ids: ['67576', '66494', '90455']
# Processing qid: 158013
# First few doc_ids: ['76531', '238384', '136707']
# Processing qid: 140278
# First few doc_ids: ['63022', '61651', '508541']
# Processing qid: 156267
# First few doc_ids: ['58807', '58753', '58756']
# Processing qid: 127354
# First few doc_ids: ['62982', '145726', '235969']
# Processing qid: 165341
# First few doc_ids: ['149717', '9525', '246731']
# Processing qid: 125823
# First few doc_ids: ['89136', '1793', '66927']
# Processing qid: 36417
# First few doc_ids: ['92849', '114628', '254669']
# Processing qid: 161378
# First few doc_ids: ['615559', '16656', '98749']
# Processing qid: 100083
# First few doc_ids: ['245382', '247764', '46718']
# Processing qid: 39478
# First few doc_ids: ['73035', '39666', '72253']
# Processing qid: 90930
# First few doc_ids: ['605348', '617121', '538796']
# Processing qid: 141273
# First few doc_ids: ['62292', '65552', '23878']
# Processing qid: 88440
# First few doc_ids: ['61944', '64653', '66440']
# Processing qid: 46600
# First few doc_ids: ['624345', '259086', '457073']
# Processing qid: 146040
# First few doc_ids: ['589451', '562896', '223313']
# Processing qid: 34848
# First few doc_ids: ['100453', '638666', '554344']
# Processing qid: 69843
# First few doc_ids: ['5292', '556683', '96291']
# Processing qid: 130655
# First few doc_ids: ['87999', '82695', '153626']
# Processing qid: 73287
# First few doc_ids: ['22430', '22432', '22438']
# Processing qid: 78450
# First few doc_ids: ['19410', '29898', '100996']
# Processing qid: 88272
# First few doc_ids: ['176151', '182431', '68327']
# Processing qid: 55915
# First few doc_ids: ['124101', '248621', '124102']
# Processing qid: 143099
# First few doc_ids: ['78902', '61246', '61227']
# Processing qid: 63246
# First few doc_ids: ['132302', '61871', '21150']
# Processing qid: 1460
# First few doc_ids: ['23410', '143901', '118582']
# Processing qid: 31604
# First few doc_ids: ['49196', '630632', '494525']
# Processing qid: 43822
# First few doc_ids: ['52263', '101491', '141819']
# Processing qid: 124188
# First few doc_ids: ['200556', '15842', '4422']
# Processing qid: 122868
# ...
# Processing qid: 85726
# First few doc_ids: ['134739', '206251', '115979']
# Processing qid: 166350
# First few doc_ids: ['14944', '102409', '14929']
# Processing qid: 40531
# First few doc_ids: ['34786', '32341', '245400']
# Processing qid: 24411
# First few doc_ids: ['88790', '227980', '62957']
# Processing qid: 59333
# First few doc_ids: ['58152', '4569', '81942']
# Processing qid: 32088
# First few doc_ids: ['95851', '135371', '155095']
# Processing qid: 88342
# First few doc_ids: ['160454', '115874', '121294']
# Processing qid: 31251
# First few doc_ids: ['116197', '85972', '228293']
# Processing qid: 123281
# First few doc_ids: ['106441', '65263', '163448']
# Processing qid: 82482
# First few doc_ids: ['168748', '153884', '141204']
# Processing qid: 94662
# First few doc_ids: ['32400', '130541', '167527']
# Processing qid: 65643
# First few doc_ids: ['35634', '35637', '35641']
# Processing qid: 79836
# First few doc_ids: ['5802', '150924', '249514']
# Processing qid: 14864
# First few doc_ids: ['78050', '78048', '194034']
# Processing qid: 55336
# First few doc_ids: ['58172', '499122', '499133']
# Processing qid: 35548
# First few doc_ids: ['101235', '491308', '84235']
# Processing qid: 153601
# First few doc_ids: ['181177', '111586', '185342']
# Processing qid: 44963
# First few doc_ids: ['185198', '117015', '57738']
# Processing qid: 149379
# First few doc_ids: ['71751', '228690', '186372']
# Processing qid: 35888
# First few doc_ids: ['101634', '127401', '101635']
# Processing qid: 8669
# First few doc_ids: ['148101', '59944', '156365']
# Processing qid: 22740
# First few doc_ids: ['234253', '86893', '180639']
# Processing qid: 61136
# First few doc_ids: ['109492', '76136', '211849']
# Processing qid: 103032
# First few doc_ids: ['207206', '153447', '70051']
# Processing qid: 9008
# First few doc_ids: ['54151', '225129', '60470']
# Processing qid: 105511
# First few doc_ids: ['164708', '185787', '119131']
# Processing qid: 107172
# First few doc_ids: ['3343', '181504', '168158']
# Processing qid: 116206
# First few doc_ids: ['76601', '76600', '128305']
# Processing qid: 42379
# First few doc_ids: ['252579', '255395', '89792']
# Processing qid: 122972
# First few doc_ids: ['161717', '187154', '104131']
# Processing qid: 43628
# First few doc_ids: ['135961', '93389', '110335']
# Processing qid: 129318
# First few doc_ids: ['55471', '54754', '540815']
# Processing qid: 26872
# First few doc_ids: ['235856', '133188', '30971']
# Processing qid: 21698
# First few doc_ids: ['45096', '68999', '124361']
# Processing qid: 70379
# First few doc_ids: ['140306', '130030', '130031']
# Processing qid: 44046
# First few doc_ids: ['461883', '128126', '17709']
# Processing qid: 47227
# First few doc_ids: ['66707', '588783', '1930']
# Processing qid: 124820
# First few doc_ids: ['93381', '58996', '452228']
# Processing qid: 121779
# First few doc_ids: ['154696', '34627', '62019']
# Processing qid: 24871
# First few doc_ids: ['89302', '32015', '235896']
# Processing qid: 163322
# First few doc_ids: ['29195', '69036', '102623']
# Processing qid: 416
# First few doc_ids: ['64098', '140026', '175266']
# Processing qid: 151107
# First few doc_ids: ['230643', '188406', '248491']
# Processing qid: 273
# First few doc_ids: ['1112', '82451', '87256']
# Processing qid: 21702
# First few doc_ids: ['87898', '79263', '147400']
# Processing qid: 161308
# First few doc_ids: ['154575', '177266', '221818']
# Processing qid: 30429
# First few doc_ids: ['65785', '2263', '95531']
# Processing qid: 62348
# First few doc_ids: ['43420', '31243', '158937']
# Processing qid: 169594
# First few doc_ids: ['35204', '35202', '200627']
# Processing qid: 52927
# First few doc_ids: ['5881', '167584', '633070']
# Processing qid: 77586
# First few doc_ids: ['209144', '788', '632192']
# Processing qid: 28022
# First few doc_ids: ['146776', '145239', '50228']
# Processing qid: 20645
# First few doc_ids: ['250735', '165132', '146493']
# Processing qid: 35831
# First few doc_ids: ['27509', '441948', '630431']
# Processing qid: 70805
# First few doc_ids: ['140788', '140789', '147707']
# Processing qid: 144805
# First few doc_ids: ['40681', '40682', '60234']
# Processing qid: 104036
# First few doc_ids: ['61932', '44872', '164370']
# Processing qid: 51442
# First few doc_ids: ['66866', '23700', '65576']
# Processing qid: 119672
# First few doc_ids: ['173531', '134563', '18331']
# Processing qid: 2161
# First few doc_ids: ['77044', '63837', '181823']
# Processing qid: 157011
# First few doc_ids: ['90882', '40866', '177284']
# Processing qid: 9229
# First few doc_ids: ['212689', '212688', '71771']
# Processing qid: 12668
# First few doc_ids: ['509608', '78740', '240483']
# Processing qid: 30253
# First few doc_ids: ['55183', '23700', '39410']
# Processing qid: 77099
# First few doc_ids: ['116789', '239798', '168281']
# Processing qid: 60549
# First few doc_ids: ['34367', '68242', '70088']
# Processing qid: 51719
# First few doc_ids: ['616002', '119398', '119401']
# Processing qid: 80290
# First few doc_ids: ['166341', '614800', '151432']
# Processing qid: 133568
# First few doc_ids: ['59942', '38085', '197361']
# Processing qid: 53431
# First few doc_ids: ['442249', '642094', '480432']
# Processing qid: 12464
# First few doc_ids: ['44171', '44168', '41755']
# Processing qid: 157828
# First few doc_ids: ['164984', '224500', '241495']
# Processing qid: 2320
# First few doc_ids: ['212845', '57690', '210002']
# Processing qid: 78529
# First few doc_ids: ['257534', '623226', '504852']
# Processing qid: 116307
# First few doc_ids: ['58786', '58785', '58788']
# Processing qid: 154832
# First few doc_ids: ['234801', '83437', '83438']
# Processing qid: 82441
# First few doc_ids: ['77387', '81684', '61899']
# Processing qid: 89865
# First few doc_ids: ['99174', '38836', '234572']
# Processing qid: 1619
# First few doc_ids: ['59165', '59171', '59193']
# Processing qid: 63675
# First few doc_ids: ['132784', '481080', '96628']
# Processing qid: 1273
# First few doc_ids: ['62858', '5153', '599828']
# Processing qid: 51190
# First few doc_ids: ['47168', '465319', '533041']
# Processing qid: 137009
# First few doc_ids: ['214892', '214891', '75781']
# Processing qid: 133521
# First few doc_ids: ['211004', '39769', '102161']
# Processing qid: 36801
# First few doc_ids: ['81833', '64845', '65634']
# Processing qid: 114645
# First few doc_ids: ['45638', '76930', '578919']
# Processing qid: 135587
# First few doc_ids: ['217624', '213306', '464810']
# Processing qid: 135791
# First few doc_ids: ['31456', '31461', '253649']
# Processing qid: 57119
# First few doc_ids: ['74049', '110245', '208450']
# Processing qid: 2428
# First few doc_ids: ['64137', '19988', '234575']
# Processing qid: 153545
# First few doc_ids: ['196420', '185100', '70626']
# Processing qid: 59365
# First few doc_ids: ['127953', '144750', '45472']
# Processing qid: 627
# First few doc_ids: ['201679', '62125', '84786']
# Processing qid: 158913
# First few doc_ids: ['239399', '120353', '18512']
# Processing qid: 135286
# First few doc_ids: ['212979', '74517', '89859']
# Processing qid: 98329
# First few doc_ids: ['12630', '75451', '12633']
# Processing qid: 67933
# First few doc_ids: ['137547', '14735', '74864']
# Processing qid: 124800
# First few doc_ids: ['156808', '201248', '120048']
# Processing qid: 142916
# First few doc_ids: ['64594', '157234', '636780']
# Processing qid: 154399
# First few doc_ids: ['590328', '59590', '186069']
# Processing qid: 150397
# First few doc_ids: ['70242', '7848', '40795']
# Processing qid: 165062
# First few doc_ids: ['188053', '87005', '59620']
# Processing qid: 98526
# First few doc_ids: ['16709', '53302', '126533']
# Processing qid: 104670
# First few doc_ids: ['458264', '13894', '537541']
# Processing qid: 94911
# First few doc_ids: ['61685', '167244', '61687']
# Processing qid: 93571
# First few doc_ids: ['166320', '164153', '518065']
# Processing qid: 80488
# First few doc_ids: ['12732', '24773', '41862']
# Processing qid: 21043
# First few doc_ids: ['25905', '220812', '119000']
# Processing qid: 122949
# First few doc_ids: ['199163', '206901', '2557']
# Processing qid: 120263
# First few doc_ids: ['73223', '138837', '58761']
# Processing qid: 107637
# First few doc_ids: ['236532', '96767', '260637']
# Processing qid: 19303
# First few doc_ids: ['24105', '53890', '64407']
# Processing qid: 149526
# First few doc_ids: ['142357', '67814', '247200']
# Processing qid: 174226
# First few doc_ids: ['65494', '510194', '127649']
# Processing qid: 139477
# First few doc_ids: ['456537', '456535', '68382']
# Processing qid: 98074
# First few doc_ids: ['32755', '223960', '13839']
# Processing qid: 14586
# First few doc_ids: ['63997', '56825', '56810']
# Processing qid: 142619
# First few doc_ids: ['221170', '45887', '55594']
# Processing qid: 28309
# First few doc_ids: ['93158', '82209', '93157']
# Processing qid: 124170
# First few doc_ids: ['75932', '204803', '75931']
# Processing qid: 70253
# First few doc_ids: ['63429', '200860', '63428']
# Processing qid: 122151
# First few doc_ids: ['74472', '187027', '58954']
# Processing qid: 39292
# First few doc_ids: ['239141', '188861', '123196']
# Processing qid: 36979
# First few doc_ids: ['52685', '1855', '31055']
# Processing qid: 122376
# First few doc_ids: ['86187', '217332', '102275']
# Processing qid: 76004
# First few doc_ids: ['503013', '137435', '86294']
# Processing qid: 71847
# First few doc_ids: ['1616', '1618', '634849']
# Processing qid: 58542
# First few doc_ids: ['54645', '49287', '68365']
# Processing qid: 125356
# First few doc_ids: ['201872', '27061', '82503']
# Processing qid: 103672
# First few doc_ids: ['619081', '545154', '567143']
# Processing qid: 126551
# First few doc_ids: ['88030', '69793', '50709']
# Processing qid: 96553
# First few doc_ids: ['169653', '28834', '123016']
# Processing qid: 10423
# First few doc_ids: ['27233', '476475', '534829']
# Processing qid: 21700
# First few doc_ids: ['239685', '201850', '87898']
# Processing qid: 62657
# First few doc_ids: ['155643', '189817', '48277']
# Processing qid: 91650
# First few doc_ids: ['164171', '164172', '164173']
# Processing qid: 122566
# First few doc_ids: ['109848', '23971', '64923']
# Processing qid: 61866
# First few doc_ids: ['36084', '130772', '56194']
# Processing qid: 64421
# First few doc_ids: ['181823', '125624', '73340']
# Processing qid: 46727
# First few doc_ids: ['113809', '18852', '40278']
# Processing qid: 159914
# First few doc_ids: ['64176', '11513', '70161']
# Processing qid: 59178
# First few doc_ids: ['73574', '8210', '63207']
# Processing qid: 94845
# First few doc_ids: ['49039', '533763', '592831']
# Processing qid: 9284
# First few doc_ids: ['248458', '243150', '618353']
# Processing qid: 133090
# First few doc_ids: ['210515', '566147', '463278']
# Processing qid: 31616
# First few doc_ids: ['58963', '58961', '8849']
# Processing qid: 33623
# First few doc_ids: ['99089', '252662', '615273']
# Processing qid: 96986
# First few doc_ids: ['595459', '496348', '32117']
# Processing qid: 167795
# First few doc_ids: ['48415', '96654', '48469']
# Processing qid: 89585
# First few doc_ids: ['161859', '86082', '202037']
# Processing qid: 47805
# First few doc_ids: ['149819', '70329', '68833']
# Processing qid: 74411
# First few doc_ids: ['11469', '163544', '144857']
# Processing qid: 129993
# First few doc_ids: ['255395', '235145', '116943']
# Processing qid: 115856
# First few doc_ids: ['48431', '48430', '48417']
# Processing qid: 51409
# First few doc_ids: ['119041', '31815', '10585']
# Processing qid: 120102
# First few doc_ids: ['17655', '16693', '71059']
# Processing qid: 80769
# First few doc_ids: ['87974', '87511', '184263']
# Processing qid: 146906
# First few doc_ids: ['67785', '91786', '70245']
# Processing qid: 119296
# First few doc_ids: ['58627', '105884', '58628']
# Processing qid: 120693
# First few doc_ids: ['199685', '237578', '92009']
# Processing qid: 106196
# First few doc_ids: ['85331', '38307', '41559']
# Processing qid: 8083
# First few doc_ids: ['28916', '576975', '555138']
# Processing qid: 29596
# First few doc_ids: ['48871', '82674', '111254']
# Processing qid: 63991
# First few doc_ids: ['74626', '74625', '593855']
# Processing qid: 67235
# First few doc_ids: ['123011', '132507', '76436']
# Processing qid: 37849
# First few doc_ids: ['101713', '66740', '86118']
# Processing qid: 63152
# First few doc_ids: ['57070', '57104', '55312']
# Processing qid: 139994
# First few doc_ids: ['129807', '82231', '73425']
# Processing qid: 128909
# First few doc_ids: ['220401', '118744', '57700']
# Processing qid: 143498
# First few doc_ids: ['254260', '261305', '120351']
# Processing qid: 162957
# First few doc_ids: ['202454', '97297', '101614']
# Processing qid: 139037
# First few doc_ids: ['108145', '108144', '65272']
# Processing qid: 134414
# First few doc_ids: ['36728', '211998', '85013']
# Processing qid: 13881
# First few doc_ids: ['58242', '58245', '58246']
# Processing qid: 49150
# First few doc_ids: ['70386', '94116', '93879']
# Processing qid: 140025
# First few doc_ids: ['546371', '58750', '58752']
# Processing qid: 42340
# First few doc_ids: ['108883', '164560', '443218']
# Processing qid: 76085
# First few doc_ids: ['97458', '45004', '45003']
# Processing qid: 14260
# First few doc_ids: ['77374', '181627', '181625']
# Processing qid: 47514
# First few doc_ids: ['62194', '114687', '561173']
# Processing qid: 105329
# First few doc_ids: ['21675', '21680', '21676']
# Processing qid: 35390
# First few doc_ids: ['101053', '193616', '210275']
# Processing qid: 160655
# First few doc_ids: ['24985', '87711', '239504']
# Processing qid: 44178
# First few doc_ids: ['147277', '166351', '631155']
# Processing qid: 89183
# First few doc_ids: ['196881', '513083', '144593']
# Processing qid: 150986
# First few doc_ids: ['39124', '230502', '230503']
# Processing qid: 87776
# First few doc_ids: ['570847', '467974', '550154']
# Processing qid: 157394
# First few doc_ids: ['62551', '114644', '116597']
# Processing qid: 59047
# First few doc_ids: ['134850', '127605', '31189']
# Processing qid: 149405
# First few doc_ids: ['64594', '157234', '636780']
# Processing qid: 42107
# First few doc_ids: ['2863', '66860', '25490']
# Processing qid: 38161
# First few doc_ids: ['35320', '39771', '65249']
# Processing qid: 124861
# First few doc_ids: ['531029', '470080', '201317']
# Processing qid: 98649
# First few doc_ids: ['149629', '30204', '35199']
# Processing qid: 67139
# First few doc_ids: ['140191', '6387', '537769']
# Processing qid: 108590
# First few doc_ids: ['82171', '38332', '604471']
# Processing qid: 15340
# First few doc_ids: ['11871', '61490', '90141']
# Processing qid: 69326
# First few doc_ids: ['5825', '2883', '240307']
# Processing qid: 16348
# First few doc_ids: ['182714', '57086', '57096']
# Processing qid: 107035
# First few doc_ids: ['110804', '181346', '241666']
# Processing qid: 8350
# First few doc_ids: ['126250', '211175', '557817']
# Processing qid: 100254
# First few doc_ids: ['124734', '209605', '77647']
# Processing qid: 28975
# First few doc_ids: ['93891', '204786', '36943']
# Processing qid: 93380
# First few doc_ids: ['200712', '61423', '41093']
# Processing qid: 82808
# First few doc_ids: ['191271', '154299', '154771']
# Processing qid: 13290
# First few doc_ids: ['66760', '226617', '67607']
# Processing qid: 36943
# First few doc_ids: ['32590', '26322', '32591']
# Processing qid: 11892
# First few doc_ids: ['98546', '67024', '64350']
# Processing qid: 46058
# First few doc_ids: ['83155', '113069', '113068']
# Processing qid: 96858
# First few doc_ids: ['49462', '49468', '69055']
# Processing qid: 147855
# First few doc_ids: ['249143', '104404', '524534']
# Processing qid: 134175
# First few doc_ids: ['182446', '23762', '183390']
# Processing qid: 14264
# First few doc_ids: ['252488', '19367', '64356']
# Processing qid: 3214
# First few doc_ids: ['150879', '75261', '79178']
# Processing qid: 36875
# First few doc_ids: ['112845', '216407', '250301']
# Processing qid: 92693
# First few doc_ids: ['165341', '64467', '170112']
# Processing qid: 74584
# First few doc_ids: ['75772', '71678', '230907']
# Processing qid: 109200
# First few doc_ids: ['183779', '496279', '42307']
# Processing qid: 77572
# First few doc_ids: ['184372', '58390', '239448']
# Processing qid: 67433
# First few doc_ids: ['185821', '144189', '109997']
# Processing qid: 109318
# First few doc_ids: ['586960', '23708', '238895']
# Processing qid: 42798
# First few doc_ids: ['76436', '224313', '484380']
# Processing qid: 10533
# First few doc_ids: ['73219', '8413', '567180']
# Processing qid: 46794
# First few doc_ids: ['102264', '176646', '261054']
# Processing qid: 112007
# First few doc_ids: ['520303', '88603', '250555']
# Processing qid: 14114
# First few doc_ids: ['445202', '456213', '442630']
